# %% [markdown]
# #Sample Dataset of git commit related data for OpenStack
#
# Copyright Doug Williams - 2014, 2015
#
# ###Updated: 3/12/2015
#
# ###Sources:
# - Launchpad (https://launchpad.net/nova)
# - Gerrit (https://review.openstack.org/#/q/status:open,n,z)
# - Git (https://github.com/openstack/nova)
#
# ###Data Structures:
# - combined_commits.jsonz : Basic record for each commit, integrating data from Launchpad, Gerrit and Git, as stored on disk
# - Enhanced combined_commits:  Dataset enhanced with 'guilt' data based on selected bug severity threshold.
# - Extracted features for use by dict vectorizer
#
#
# Note:  All .jsonz files are gzipped json, with individual json entries for each record.  Apply json.loads() to each individual line.
#
# ###Examples:
# - Sample entry from combined_commits.jsonz
# - Sample entry from all_blame.jsonz
# - Example of blame normalization
#
# ###History
# - 3/12/2015: Major update

# %% [markdown]
# # Imports

# %%
from pprint import pprint
from collections import defaultdict

import numpy as np
import numpy as np
import math
import matplotlib.pyplot as plt


import sys
sys.path.append('../dev')

from commit_analysis import load_combined_commits

from Git_Extract import  filter_bug_fix_combined_commits
from Git_Extract import get_commit_ordering_min_max

from commit_analysis import load_core_analysis_data
from commit_analysis import fit_features
from commit_analysis import extract_features
from commit_analysis import extract_features_helper
from commit_analysis import compute_guilt
from commit_analysis import autoset_threshold
from BugFixWorkflow import compute_selected_bug_fixes

from BugFixWorkflow import commit_postprocessing
from BugFixWorkflow import find_legacy_cutoff

# from commit_analysis import blame_compute_normalized_guilt
# from commit_analysis import normalize_blame_by_file

# %% [raw]
# from pprint import pprint
# from collections import defaultdict
# import sys
# sys.path.append('./dev')
# from jp_load_dump import jload

# %% [markdown]
# # Configuration

# %%
# PROJECT = 'nova'
# PROJECT = 'swift'
# PROJECT = 'cinder'
PROJECT = 'heat'
# PROJECT = 'glance'

# IMPORTANCE = 'high+'
IMPORTANCE = 'med+'

# %% [markdown]
# # Sample entry from < project >_combined_commits.jsonz

# %%
combined_commits = load_combined_commits(PROJECT)

# %% [markdown]
# ### Basic Commit entry (dict)

# %% [markdown]
# ###### Structure

# %%
pprint(combined_commits.values()[0].keys())
# Out:
# [u'files',
#  u'committer',
#  u'ancestors',
#  u'unfiltered_files',
#  u'blueprint',
#  u'author',
#  u'change_details',
#  u'cid',
#  u'on_mainline',
#  u'date',
#  u'parents',
#  u'bug_details',
#  u'msg',
#  u'distance_from_mainline',
#  u'children',
#  u'is_master_commit',
#  u'on_master_branch']

# %% [markdown]
# ###### Sample data

# %%
pprint(combined_commits.items()[0])
# Out:
# (u'a7d10dc43b0d2baa48cabd97781098d14208ecec',
#  {u'ancestors': False,
#   u'author': u'<git.Actor "Jenkins <jenkins@review.openstack.org>">',
#   u'blueprint': False,
#   u'bug_details': {},
#   u'change_details': False,
#   u'children': [u'ad039c26828cecaa9a657bedb5106304b58634b0',
#                 u'b0903a5598b6812342e230a03ff0310d068cb450',
#                 u'8faef30895d5b3550d50672fc454acc37992008a'],
#   u'cid': u'a7d10dc43b0d2baa48cabd97781098d14208ecec',
#   u'committer': u'<git.Actor "Gerrit Code Review <review@openstack.org>">',
#   u'date': 1411637242,
#   u'distance_from_mainline': 0,
#   u'files': [u'heat/api/openstack/v1/stacks.py'],
#   u'is_master_commit': False,
#   u'msg': u'Merge "Convert parse error to text type"',
#   u'on_mainline': True,
#   u'on_master_branch': True,
#   u'parents': [u'b8ed38807e227ab3a28ad5576615656b8f781fdf',
#                u'58a094238bbfa4c652d63a000854e77cf894d345'],
#   u'unfiltered_files': [u'heat/api/openstack/v1/stacks.py']})

# %% [markdown]
# ### Commit with associated bug

# %% [markdown]
# ###### Dict Structure has data in 'bugs' and 'bug_details' field

# %%
sample_commits = [v for k,v in combined_commits.items() if 'bug_details' in v and v['bug_details']]
pprint (sample_commits[0].keys() )
# Out:
# [u'files',
#  u'committer',
#  u'ancestors',
#  u'unfiltered_files',
#  u'blueprint',
#  u'author',
#  u'change_id',
#  u'is_master_commit',
#  u'bugs',
#  u'on_mainline',
#  u'msg',
#  u'cid',
#  u'parents',
#  u'bug_details',
#  u'change_details',
#  u'date',
#  u'distance_from_mainline',
#  u'children',
#  u'on_master_branch']

# %%
pprint (sample_commits[0]['bugs'] )
# Out:
# [u'1268614']

# %% [markdown]
# ###### bug_details wit a dict with one entry per bug

# %%
pprint (sample_commits[0]['bug_details'].keys() )
# Out:
# [u'1268614']

# %%
pprint (sample_commits[0]['bug_details'].values()[0].keys())
# Out:
# [u'status',
#  u'security_related',
#  u'description',
#  u'tags',
#  u'importance',
#  u'commits',
#  u'title',
#  u'messages',
#  u'name',
#  u'message_count',
#  u'heat',
#  u'date_created',
#  u'activity',
#  u'self_link',
#  u'information_type',
#  u'cves',
#  u'duplicate_of',
#  u'id',
#  u'resource_type',
#  u'attachments']

# %% [markdown]
# ###### Detailed bug entry

# %%
pprint (sample_commits[0]['bug_details'])
# Out:
# {u'1268614': {u'activity': [],
#               u'attachments': [],
#               u'commits': [],
#               u'cves': [],
#               u'date_created': u'2014-01-13 14:46:21.161906+00:00',
#               u'description': u"I see several changes, including https://review.openstack.org/#/c/63735/ , failed pep8 gating with error from check_uptodate tool:\n\n\n2014-01-13 14:06:39.643 | pep8 runtests: commands[1] | /home/jenkins/workspace/gate-nova-pep8/tools/config/check_uptodate.sh\n2014-01-13 14:06:39.649 |   /home/jenkins/workspace/gate-nova-pep8$ /home/jenkins/workspace/gate-nova-pep8/tools/config/check_uptodate.sh \n2014-01-13 14:06:43.581 | 2741,2746d2740\n2014-01-13 14:06:43.581 | < # (optional) indicate whether to set the X-Service-Catalog\n2014-01-13 14:06:43.581 | < # header. If False, middleware will not ask for service\n2014-01-13 14:06:43.581 | < # catalog on token validation and will not set the X-Service-\n2014-01-13 14:06:43.581 | < # Catalog header. (boolean value)\n2014-01-13 14:06:43.581 | < #include_service_catalog=true\n2014-01-13 14:06:43.582 | < \n2014-01-13 14:06:43.582 | E: nova.conf.sample is not up to date, please run tools/config/generate_sample.sh\n2014-01-13 14:06:43.582 | ERROR: InvocationError: '/home/jenkins/workspace/gate-nova-pep8/tools/config/check_uptodate.sh'",
#               u'duplicate_of': u'None',
#               u'heat': u'34',
#               u'id': u'1268614',
#               u'importance': u'Undecided',
#               u'information_type': u'Public',
#               u'message_count': u'17',
#               u'messages': [{u'bug_attachments': [],
#                              u'content': u"I see several changes, including https://review.openstack.org/#/c/63735/ , failed pep8 gating with error from check_uptodate tool:\n\n\n2014-01-13 14:06:39.643 | pep8 runtests: commands[1] | /home/jenkins/workspace/gate-nova-pep8/tools/config/check_uptodate.sh\n2014-01-13 14:06:39.649 |   /home/jenkins/workspace/gate-nova-pep8$ /home/jenkins/workspace/gate-nova-pep8/tools/config/check_uptodate.sh \n2014-01-13 14:06:43.581 | 2741,2746d2740\n2014-01-13 14:06:43.581 | < # (optional) indicate whether to set the X-Service-Catalog\n2014-01-13 14:06:43.581 | < # header. If False, middleware will not ask for service\n2014-01-13 14:06:43.581 | < # catalog on token validation and will not set the X-Service-\n2014-01-13 14:06:43.581 | < # Catalog header. (boolean value)\n2014-01-13 14:06:43.581 | < #include_service_catalog=true\n2014-01-13 14:06:43.582 | < \n2014-01-13 14:06:43.582 | E: nova.conf.sample is not up to date, please run tools/config/generate_sample.sh\n2014-01-13 14:06:43.582 | ERROR: InvocationError: '/home/jenkins/workspace/gate-nova-pep8/tools/config/check_uptodate.sh'",
#                              u'date_created': u'2014-01-13 14:46:21.161906+00:00',
#                              u'resource_type': u'#message',
#                              u'self_link': u'https://api.launchpad.net/1.0/nova/+bug/1268614/comments/0',
#                              u'subject': u'pep8 gating fails due to tools/config/check_uptodate.sh'},
#                             {u'bug_attachments': [],
#                              u'content': u"Looks like it's due to updated python-keystoneclient. With python-keystoneclient 0.4.1 check_uptodate.sh works just fine. Keystoneclient 0.4.2 introduces include_service_catalog option in commit a97b293501fa504dd154fc921809a40bc2a34049.",
#                              u'date_created': u'2014-01-13 14:49:28.599175+00:00',
#                              u'resource_type': u'#message',
#                              u'self_link': u'https://api.launchpad.net/1.0/nova/+bug/1268614/comments/1',
#                              u'subject': u'Re: pep8 gating fails due to tools/config/check_uptodate.sh'},
#                             {u'bug_attachments': [],
#                              u'content': u'I proposed change for master: https://review.openstack.org/#/c/66346/',
#                              u'date_created': u'2014-01-13 15:59:43.352178+00:00',
#                              u'resource_type': u'#message',
#                              u'self_link': u'https://api.launchpad.net/1.0/nova/+bug/1268614/comments/2',
#                              u'subject': u'Re: pep8 gating fails due to tools/config/check_uptodate.sh'},
#                             {u'bug_attachments': [],
#                              u'content': u"This bug also affect Ceilometer:\n\n2014-01-13 18:15:12.965 | py27 runtests: commands[1] | /home/jenkins/workspace/gate-ceilometer-python27/tools/config/check_uptodate.sh\n2014-01-13 18:15:13.947 | 838,843d837\n2014-01-13 18:15:13.947 | < # (optional) indicate whether to set the X-Service-Catalog\n2014-01-13 18:15:13.947 | < # header. If False, middleware will not ask for service\n2014-01-13 18:15:13.947 | < # catalog on token validation and will not set the X-Service-\n2014-01-13 18:15:13.947 | < # Catalog header. (boolean value)\n2014-01-13 18:15:13.947 | < #include_service_catalog=true\n2014-01-13 18:15:13.947 | < \n2014-01-13 18:15:13.948 | E: ceilometer.conf.sample is not up to date, please run tools/config/generate_sample.sh\n2014-01-13 18:15:13.948 | ERROR: InvocationError: '/home/jenkins/workspace/gate-ceilometer-python27/tools/config/check_uptodate.sh'\n",
#                              u'date_created': u'2014-01-13 19:21:39.228456+00:00',
#                              u'resource_type': u'#message',
#                              u'self_link': u'https://api.launchpad.net/1.0/nova/+bug/1268614/comments/3',
#                              u'subject': u'Re: pep8 gating fails due to tools/config/check_uptodate.sh'},
#                             {u'bug_attachments': [],
#                              u'content': u'Fix proposed to branch: master\nReview: https://review.openstack.org/66402',
#                              u'date_created': u'2014-01-13 19:28:00.763571+00:00',
#                              u'resource_type': u'#message',
#                              u'self_link': u'https://api.launchpad.net/1.0/nova/+bug/1268614/comments/4',
#                              u'subject': u'Fix proposed to ceilometer (master)'},
#                             {u'bug_attachments': [],
#                              u'content': u'Reviewed:  https://review.openstack.org/66346\nCommitted: https://git.openstack.org/cgit/openstack/nova/commit/?id=7e9f0de5c1b4703f3477062609c5bf43b5cf91dc\nSubmitter: Jenkins\nBranch:    master\n\ncommit 7e9f0de5c1b4703f3477062609c5bf43b5cf91dc\nAuthor: Ivan A. Melnikov <email address hidden>\nDate:   Mon Jan 13 18:51:17 2014 +0400\n\n    Update nova.conf.sample\n    \n    Recent version of python-keystoneclient introduces new option,\n    include_service_catalog, so nova.conf.sample should be updated.\n    \n    Closes-bug: #1268614\n    Change-Id: I8f5f76770b8af8002f6a296594303224ec37846c\n',
#                              u'date_created': u'2014-01-13 19:30:41.837377+00:00',
#                              u'resource_type': u'#message',
#                              u'self_link': u'https://api.launchpad.net/1.0/nova/+bug/1268614/comments/5',
#                              u'subject': u'Fix merged to nova (master)'},
#                             {u'bug_attachments': [],
#                              u'content': u'Fix proposed to branch: master\nReview: https://review.openstack.org/66428',
#                              u'date_created': u'2014-01-13 20:52:59.131551+00:00',
#                              u'resource_type': u'#message',
#                              u'self_link': u'https://api.launchpad.net/1.0/nova/+bug/1268614/comments/6',
#                              u'subject': u'Fix proposed to heat (master)'},
#                             {u'bug_attachments': [],
#                              u'content': u'Reviewed:  https://review.openstack.org/66428\nCommitted: https://git.openstack.org/cgit/openstack/heat/commit/?id=f75369eecfcaa185ed10c6be8727428f79b7bff0\nSubmitter: Jenkins\nBranch:    master\n\ncommit f75369eecfcaa185ed10c6be8727428f79b7bff0\nAuthor: Jason Dunsmore <email address hidden>\nDate:   Mon Jan 13 14:51:19 2014 -0600\n\n    Update heat.conf.sample\n    \n    A new version of python-keystoneclient introduces an option,\n    include_service_catalog, so heat.conf.sample should be updated.\n    \n    Closes-Bug: #1268614\n    Change-Id: I3caf012d1ecfd852b736f52a1269f742449ffee9\n',
#                              u'date_created': u'2014-01-14 00:41:29.579949+00:00',
#                              u'resource_type': u'#message',
#                              u'self_link': u'https://api.launchpad.net/1.0/nova/+bug/1268614/comments/7',
#                              u'subject': u'Fix merged to heat (master)'},
#                             {u'bug_attachments': [],
#                              u'content': u'Related fix proposed to branch: master\nReview: https://review.openstack.org/66487',
#                              u'date_created': u'2014-01-14 02:54:23.543284+00:00',
#                              u'resource_type': u'#message',
#                              u'self_link': u'https://api.launchpad.net/1.0/nova/+bug/1268614/comments/8',
#                              u'subject': u'Related fix proposed to heat (master)'},
#                             {u'bug_attachments': [],
#                              u'content': u'Related fix proposed to branch: master\nReview: https://review.openstack.org/66512',
#                              u'date_created': u'2014-01-14 07:42:49.722219+00:00',
#                              u'resource_type': u'#message',
#                              u'self_link': u'https://api.launchpad.net/1.0/nova/+bug/1268614/comments/9',
#                              u'subject': u'Related fix proposed to cinder (master)'},
#                             {u'bug_attachments': [],
#                              u'content': u'Reviewed:  https://review.openstack.org/66402\nCommitted: https://git.openstack.org/cgit/openstack/ceilometer/commit/?id=76c06e03eaef0c66689c62aece24baee0b372644\nSubmitter: Jenkins\nBranch:    master\n\ncommit 76c06e03eaef0c66689c62aece24baee0b372644\nAuthor: Ildiko Vancsa <email address hidden>\nDate:   Mon Jan 13 20:26:07 2014 +0100\n\n    Update ceilometer.conf.sample\n    \n    Due to python-keystoneclient update.\n    \n    Change-Id: Ie683d3fbf8086d2be6a2fbe19374b8d31abaf976\n    Closes-bug: #1268614\n',
#                              u'date_created': u'2014-01-14 19:05:55.786992+00:00',
#                              u'resource_type': u'#message',
#                              u'self_link': u'https://api.launchpad.net/1.0/nova/+bug/1268614/comments/10',
#                              u'subject': u'Fix merged to ceilometer (master)'},
#                             {u'bug_attachments': [],
#                              u'content': u'Reviewed:  https://review.openstack.org/66372\nCommitted: https://git.openstack.org/cgit/openstack/cinder/commit/?id=6f1e6f473c84657b33dde094cb4b047fbdaf7c45\nSubmitter: Jenkins\nBranch:    master\n\ncommit 6f1e6f473c84657b33dde094cb4b047fbdaf7c45\nAuthor: Eric Harney <email address hidden>\nDate:   Mon Jan 13 12:19:12 2014 -0500\n\n    Update cinder.conf.sample for keystoneclient change\n    \n    A new version of python-keystoneclient adds the\n    "include_service_catalog" option, so the sample conf needs to be\n    updated.\n    \n    Closes-Bug: #1268614\n    \n    Change-Id: Ie6913e481caf61ee517c1c101565401fe33c60d6\n',
#                              u'date_created': u'2014-01-16 04:56:50.104806+00:00',
#                              u'resource_type': u'#message',
#                              u'self_link': u'https://api.launchpad.net/1.0/nova/+bug/1268614/comments/11',
#                              u'subject': u'Fix merged to cinder (master)'},
#                             {u'bug_attachments': [],
#                              u'content': u'Fix proposed to branch: stable/havana\nReview: https://review.openstack.org/67200',
#                              u'date_created': u'2014-01-16 16:07:13.740421+00:00',
#                              u'resource_type': u'#message',
#                              u'self_link': u'https://api.launchpad.net/1.0/nova/+bug/1268614/comments/12',
#                              u'subject': u'Fix proposed to ceilometer (stable/havana)'},
#                             {u'bug_attachments': [],
#                              u'content': u'Reviewed:  https://review.openstack.org/67200\nCommitted: https://git.openstack.org/cgit/openstack/ceilometer/commit/?id=16eb199124e73df48a15193ad31b681e382becc8\nSubmitter: Jenkins\nBranch:    stable/havana\n\ncommit 16eb199124e73df48a15193ad31b681e382becc8\nAuthor: Ildiko Vancsa <email address hidden>\nDate:   Mon Jan 13 20:26:07 2014 +0100\n\n    Update ceilometer.conf.sample\n    \n    Due to python-keystoneclient update.\n    \n    Change-Id: Ie683d3fbf8086d2be6a2fbe19374b8d31abaf976\n    Closes-bug: #1268614\n    (cherry picked from commit 76c06e03eaef0c66689c62aece24baee0b372644)\n',
#                              u'date_created': u'2014-01-18 09:53:19.824128+00:00',
#                              u'resource_type': u'#message',
#                              u'self_link': u'https://api.launchpad.net/1.0/nova/+bug/1268614/comments/13',
#                              u'subject': u'Fix merged to ceilometer (stable/havana)'},
#                             {u'bug_attachments': [],
#                              u'content': u"This will break us next:\n\nhttps://github.com/openstack/python-keystoneclient/commit/8744cb674165542df8f711fbabf129c5005e997a\n\nSeems that check_uptodate needs to change somehow, otherwise we're always going to be reacting to this.",
#                              u'date_created': u'2014-01-22 15:42:02.730156+00:00',
#                              u'resource_type': u'#message',
#                              u'self_link': u'https://api.launchpad.net/1.0/nova/+bug/1268614/comments/14',
#                              u'subject': u'Re: pep8 gating fails due to tools/config/check_uptodate.sh'},
#                             {u'bug_attachments': [],
#                              u'content': u"Well, check_uptodate is doing its job, the problem is that the project sample config includes config options imported from another project, so when that project changes the nova.conf.sample needs to change too.\n\nI see a couple of options to address this:\n\n1) Set up a Jenkins job that triggers on keystoneclient releases to check whether it changed their config options and automatically propose an update to the other projects.  I expect this could work like the requirements sync job.\n\n2) Move the keystoneclient config back to a separate file and don't automatically generate it.  This will likely result in it getting out of date again though.  I assume that's why we started including keystoneclient directly in the generated config.",
#                              u'date_created': u'2014-01-22 16:29:13.420489+00:00',
#                              u'resource_type': u'#message',
#                              u'self_link': u'https://api.launchpad.net/1.0/nova/+bug/1268614/comments/15',
#                              u'subject': u'Re: pep8 gating fails due to tools/config/check_uptodate.sh'},
#                             {u'bug_attachments': [],
#                              u'content': u'This should not be considered fixed until the projects are not going to fail with this again when auth_token middleware config changes.',
#                              u'date_created': u'2014-01-24 13:21:52.965361+00:00',
#                              u'resource_type': u'#message',
#                              u'self_link': u'https://api.launchpad.net/1.0/nova/+bug/1268614/comments/16',
#                              u'subject': u'Re: pep8 gating fails due to tools/config/check_uptodate.sh'}],
#               u'name': u'None',
#               u'resource_type': u'#bug',
#               u'security_related': u'False',
#               u'self_link': u'https://api.launchpad.net/1.0/bugs/1268614',
#               u'status': u'Fix Released',
#               u'tags': [u'in-stable-havana'],
#               u'title': u'pep8 gating fails due to tools/config/check_uptodate.sh'}}

# %% [markdown]
# ### Sample commit with Gerrit Data

# %% [markdown]
# ###### Contains data in 'change_id' and 'change_detail' fields

# %%
sample_commits = [v for k,v in combined_commits.items() if 'change_details' in v and v['change_details']]
pprint (sample_commits[0].keys() )
# Out:
# [u'files',
#  u'committer',
#  u'ancestors',
#  u'unfiltered_files',
#  u'blueprint',
#  u'author',
#  u'change_id',
#  u'is_master_commit',
#  u'bugs',
#  u'on_mainline',
#  u'msg',
#  u'cid',
#  u'parents',
#  u'bug_details',
#  u'change_details',
#  u'date',
#  u'distance_from_mainline',
#  u'children',
#  u'on_master_branch']

# %%
pprint (sample_commits[0]['change_id'] )
# Out:
# u'I3caf012d1ecfd852b736f52a1269f742449ffee9'

# %% [markdown]
# ###### Structure of change detail - data extracted from Gerrit

# %%
pprint (sample_commits[0]['change_details'].keys() )
# Out:
# [u'status',
#  u'project',
#  u'updated',
#  u'created',
#  u'change_id',
#  u'labels',
#  u'messages',
#  u'kind',
#  u'topic',
#  u'owner',
#  u'branch',
#  u'_sortkey',
#  u'_number',
#  u'id',
#  u'subject']

# %% [markdown]
# ###### Sample change_detail entry

# %%
pprint (sample_commits[0]['change_details'] )
# Out:
# {u'_number': 66428,
#  u'_sortkey': u'002a6e090001037c',
#  u'branch': u'master',
#  u'change_id': u'I3caf012d1ecfd852b736f52a1269f742449ffee9',
#  u'created': u'2014-01-13 20:52:50.000000000',
#  u'id': u'openstack%2Fheat~master~I3caf012d1ecfd852b736f52a1269f742449ffee9',
#  u'kind': u'gerritcodereview#change',
#  u'labels': {u'Code-Review': {u'all': [{u'_account_id': 4257,
#                                         u'name': u'Zane Bitter',
#                                         u'value': 2}],
#                               u'approved': {u'_account_id': 4257,
#                                             u'name': u'Zane Bitter'}},
#              u'Verified': {u'all': [{u'_account_id': 3,
#                                      u'name': u'Jenkins',
#                                      u'value': 2}],
#                            u'approved': {u'_account_id': 3,
#                                          u'name': u'Jenkins'}},
#              u'Workflow': {u'all': [{u'_account_id': 4257,
#                                      u'name': u'Zane Bitter',
#                                      u'value': 1}],
#                            u'approved': {u'_account_id': 4257,
#                                          u'name': u'Zane Bitter'}}},
#  u'messages': [{u'_revision_number': 1,
#                 u'author': {u'_account_id': 3,
#                             u'avatars': [],
#                             u'name': u'Jenkins',
#                             u'username': u'jenkins'},
#                 u'date': u'2014-01-13 21:40:48.000000000',
#                 u'id': u'AAAAUH//cKA=',
#                 u'message': u'Patch Set 1: Works for me\n\nBuild succeeded.\n\n- gate-heat-pep8 http://logs.openstack.org/28/66428/1/check/gate-heat-pep8/9cb068e : SUCCESS in 3m 05s\n- gate-heat-docs http://docs-draft.openstack.org/28/66428/1/check/gate-heat-docs/7242935/doc/build/html/ : SUCCESS in 3m 58s\n- gate-heat-python26 http://logs.openstack.org/28/66428/1/check/gate-heat-python26/efc7240 : SUCCESS in 3m 19s\n- gate-heat-python27 http://logs.openstack.org/28/66428/1/check/gate-heat-python27/960c91e : SUCCESS in 3m 07s\n- check-tempest-dsvm-full http://logs.openstack.org/28/66428/1/check/check-tempest-dsvm-full/e081833 : SUCCESS in 46m 50s\n- check-tempest-dsvm-postgres-full http://logs.openstack.org/28/66428/1/check/check-tempest-dsvm-postgres-full/fa02817 : SUCCESS in 45m 16s\n- check-tempest-dsvm-neutron http://logs.openstack.org/28/66428/1/check/check-tempest-dsvm-neutron/4ea28a3 : SUCCESS in 45m 08s\n- gate-tempest-dsvm-large-ops http://logs.openstack.org/28/66428/1/check/gate-tempest-dsvm-large-ops/6da0c28 : SUCCESS in 13m 09s\n- gate-tempest-dsvm-neutron-large-ops http://logs.openstack.org/28/66428/1/check/gate-tempest-dsvm-neutron-large-ops/19cdf0c : SUCCESS in 13m 25s\n'},
#                {u'_revision_number': 1,
#                 u'author': {u'_account_id': 4257,
#                             u'avatars': [],
#                             u'email': u'zbitter@redhat.com',
#                             u'name': u'Zane Bitter',
#                             u'username': u'zaneb'},
#                 u'date': u'2014-01-13 21:52:46.000000000',
#                 u'id': u'AAAAUH//cHA=',
#                 u'message': u'Patch Set 1: Looks good to me (core reviewer); Approved\n\nApproving because this bug is blocking the queue and the fix is trivial.'},
#                {u'_revision_number': 1,
#                 u'author': {u'_account_id': 3,
#                             u'avatars': [],
#                             u'name': u'Jenkins',
#                             u'username': u'jenkins'},
#                 u'date': u'2014-01-13 21:52:47.000000000',
#                 u'id': u'AAAAUH//cG8=',
#                 u'message': u'Patch Set 1: No score\n\nStarting gate jobs.\nhttp://status.openstack.org/zuul/'},
#                {u'_revision_number': 1,
#                 u'author': {u'_account_id': 3,
#                             u'avatars': [],
#                             u'name': u'Jenkins',
#                             u'username': u'jenkins'},
#                 u'date': u'2014-01-14 00:41:23.000000000',
#                 u'id': u'AAAAUH//acY=',
#                 u'message': u'Patch Set 1: Verified\n\nBuild succeeded.\n\n- gate-heat-docs http://docs-draft.openstack.org/28/66428/1/gate/gate-heat-docs/70f7357/doc/build/html/ : SUCCESS in 4m 02s\n- gate-heat-pep8 http://logs.openstack.org/28/66428/1/gate/gate-heat-pep8/21aa4b0 : SUCCESS in 2m 56s\n- gate-heat-python26 http://logs.openstack.org/28/66428/1/gate/gate-heat-python26/a6c7350 : SUCCESS in 3m 04s\n- gate-heat-python27 http://logs.openstack.org/28/66428/1/gate/gate-heat-python27/7aa9cd3 : SUCCESS in 3m 11s\n- gate-tempest-dsvm-full http://logs.openstack.org/28/66428/1/gate/gate-tempest-dsvm-full/b94d78c : SUCCESS in 44m 56s\n- gate-tempest-dsvm-postgres-full http://logs.openstack.org/28/66428/1/gate/gate-tempest-dsvm-postgres-full/e93c756 : SUCCESS in 54m 12s\n- gate-tempest-dsvm-neutron http://logs.openstack.org/28/66428/1/gate/gate-tempest-dsvm-neutron/7709aa6 : SUCCESS in 40m 19s\n- gate-tempest-dsvm-large-ops http://logs.openstack.org/28/66428/1/gate/gate-tempest-dsvm-large-ops/48d02f0 : SUCCESS in 12m 47s\n- gate-tempest-dsvm-neutron-large-ops http://logs.openstack.org/28/66428/1/gate/gate-tempest-dsvm-neutron-large-ops/e4e585b : SUCCESS in 12m 49s\n'},
#                {u'_revision_number': 1,
#                 u'author': {u'_account_id': 3,
#                             u'avatars': [],
#                             u'name': u'Jenkins',
#                             u'username': u'jenkins'},
#                 u'date': u'2014-01-14 00:41:24.000000000',
#                 u'id': u'AAAAUH//acU=',
#                 u'message': u'Change has been successfully merged into the git repository.'}],
#  u'owner': {u'_account_id': 7253, u'name': u'Jason Dunsmore'},
#  u'project': u'openstack/heat',
#  u'status': u'MERGED',
#  u'subject': u'Update heat.conf.sample',
#  u'topic': u'pep8-bug-fix',
#  u'updated': u'2014-01-14 00:41:24.000000000'}

# %% [markdown]
# # Data after guilt processing

# %%
combined_commits = commit_postprocessing(PROJECT, importance=IMPORTANCE)
# Out:
# loading bug data
#   total LP bugs: 1388
#   Entries annotated: 536
# loading Git commit data
#   total git_commits: 7566
#   bug fix commits: 1353
#   commits with change_id: 4084
#   bug fix with change_id: 1353
# loading change data
#   total gerrit changes with detail: 4126
#   all_change_details: 4126
#   total gerrit changes: 4132
#   all_changes: 4132
# combined_commits: 7566
# Determining legacy cut-off
#   Warning: Transition Overlap: 174 days, 7:48:19
#   Setting cutoff to: 12/11/2012
# Collecting data on commits with bug fixes
#   Mainline Commits ignored due to legacy: 995  out of: 4507
#   Total commite requiring blame computation: 1113
#
# Computing Blame
# Loaded blame
#   Initial Blame cache size: 939
#   bug fix commits: 1113
# . . . . . . . . . . 100 . . . . . . . . . . 200 . . . . . . . . . . 300 . . . . . . . . . . 400 . . . . . . . . . . 500 . . . . . . . . . . 600 . . . . . . . . . . 700 . . . . . . . . . . 800 . . . . . . . . . . 900 . . . . . . . . . . 1000 . . . . . . . . . . 1100 .
#   Saving updated Blame Cache
#
# Annotating Guilt
# Identify reachable commits
#   Loaded cached reachability data
#   Initial Reachable cache size: 142
#   Samples: 142
#   Revised samples: 0
#
#   Reachable commits: 2975
# Annotating lines of code changed
#   Loaded Lines of Code Changed cache
#   Initial Lines of Code Changed cache size: 2972
# . . . . . . . . . . 1000 . . . . . . . . . . 2000 . . . . . . . . .
#   Total Alias: 37
# Order range for non-legacy comits
#   min: 387
#   max: 2972

# %% [markdown]
# ######Commit entries are now annotated based on reachability (visivbility within master branch) and imputed guilt
#
# Commit entries are also annotates with additional feature data

# %%
sample_commits = [v for k,v in combined_commits.items() if 'reachable' in v and v['reachable']]
pprint (sample_commits[0].keys() )
# Out:
# [u'committer',
#  'loc_add',
#  u'children',
#  u'on_master_branch',
#  u'ancestors',
#  u'blueprint',
#  u'author',
#  u'on_mainline',
#  u'parents',
#  'loc_detail',
#  u'msg',
#  'reachable',
#  u'files',
#  'tagged_bug_fix',
#  u'unfiltered_files',
#  'file_order',
#  'is_tracked_change',
#  u'date',
#  'loc_change',
#  u'distance_from_mainline',
#  u'cid',
#  u'change_id',
#  u'is_master_commit',
#  u'bugs',
#  'guilt',
#  u'bug_details',
#  u'change_details',
#  'author_order',
#  'order',
#  'file_order_for_author']

# %% [markdown]
# ###### Actual data

# %%
pprint (sample_commits[0] )
# Out:
# {u'ancestors': False,
#  u'author': u'<git.Actor "Roman Podoliaka <rpodolyaka@mirantis.com>">',
#  'author_order': 1,
#  u'blueprint': False,
#  u'bug_details': {u'1245863': {u'activity': [],
#                                u'attachments': [],
#                                u'commits': [{u'change_id': u'I364da88f1c581b406d51e1b584778c7dd4e2564f',
#                                              u'cid': u'11ac4dd3f899dc0f28d356bad89ec559e9d1e81f'}],
#                                u'cves': [],
#                                u'date_created': u'2013-10-29 12:07:38.147412+00:00',
#                                u'description': u'Change https://review.openstack.org/#/c/54063/ makes Fn::Select accept only string selector values. At the same time, our doc states, that the selector can be either of type string or of type integer (http://docs.openstack.org/developer/heat/template_guide/functions.html#fn-select)\n\nIf this is considered to be the correct behavior, we must update Heat docs and fix templates we are using in TripleO devtest story.',
#                                u'duplicate_of': u'None',
#                                u'heat': u'6',
#                                u'id': u'1245863',
#                                u'importance': u'Critical',
#                                u'information_type': u'Public',
#                                u'message_count': u'6',
#                                u'messages': [{u'bug_attachments': [],
#                                               u'content': u'Change https://review.openstack.org/#/c/54063/ makes Fn::Select accept only string selector values. At the same time, our doc states, that the selector can be either of type string or of type integer (http://docs.openstack.org/developer/heat/template_guide/functions.html#fn-select)',
#                                               u'date_created': u'2013-10-29 12:07:38.147412+00:00',
#                                               u'resource_type': u'#message',
#                                               u'self_link': u'https://api.launchpad.net/1.0/heat/+bug/1245863/comments/0',
#                                               u'subject': u'Fn::Select no longer accepts integer selector values'},
#                                              {u'bug_attachments': [],
#                                               u'content': u'Fix proposed to branch: master\nReview: https://review.openstack.org/54321',
#                                               u'date_created': u'2013-10-29 12:58:52.687772+00:00',
#                                               u'resource_type': u'#message',
#                                               u'self_link': u'https://api.launchpad.net/1.0/heat/+bug/1245863/comments/1',
#                                               u'subject': u'Fix proposed to heat (master)'},
#                                              {u'bug_attachments': [],
#                                               u'content': u'Alternative fix to tripleo-heat-templates is here https://review.openstack.org/#/c/54322/',
#                                               u'date_created': u'2013-10-29 13:15:47.829271+00:00',
#                                               u'resource_type': u'#message',
#                                               u'self_link': u'https://api.launchpad.net/1.0/heat/+bug/1245863/comments/2',
#                                               u'subject': u'Re: Fn::Select no longer accepts integer selector values'},
#                                              {u'bug_attachments': [],
#                                               u'content': u'https://review.openstack.org/#/c/54063/ should not have changed this behavior IMO, so this seems to be a regression which we missed at the review :(',
#                                               u'date_created': u'2013-10-29 14:32:31.589520+00:00',
#                                               u'resource_type': u'#message',
#                                               u'self_link': u'https://api.launchpad.net/1.0/heat/+bug/1245863/comments/3',
#                                               u'subject': u'Re: Fn::Select no longer accepts integer selector values'},
#                                              {u'bug_attachments': [],
#                                               u'content': u"Agreed Steven. Marking Critical, this will break a lot of templates.\n\nLet's make sure we follow up with some tempest tests.",
#                                               u'date_created': u'2013-10-29 15:16:49.697796+00:00',
#                                               u'resource_type': u'#message',
#                                               u'self_link': u'https://api.launchpad.net/1.0/heat/+bug/1245863/comments/4',
#                                               u'subject': u'Re: Fn::Select no longer accepts integer selector values'},
#                                              {u'bug_attachments': [],
#                                               u'content': u'Reviewed:  https://review.openstack.org/54321\nCommitted: http://github.com/openstack/heat/commit/11ac4dd3f899dc0f28d356bad89ec559e9d1e81f\nSubmitter: Jenkins\nBranch:    master\n\ncommit 11ac4dd3f899dc0f28d356bad89ec559e9d1e81f\nAuthor: Roman Podoliaka <email address hidden>\nDate:   Tue Oct 29 14:18:04 2013 +0200\n\n    Make Fn::Select accept an integer selector again\n    \n    Closes-Bug: #1245863\n    \n    Change-Id: I364da88f1c581b406d51e1b584778c7dd4e2564f\n',
#                                               u'date_created': u'2013-10-29 15:54:47.449346+00:00',
#                                               u'resource_type': u'#message',
#                                               u'self_link': u'https://api.launchpad.net/1.0/heat/+bug/1245863/comments/5',
#                                               u'subject': u'Fix merged to heat (master)'}],
#                                u'name': u'None',
#                                u'resource_type': u'#bug',
#                                u'security_related': u'False',
#                                u'self_link': u'https://api.launchpad.net/1.0/bugs/1245863',
#                                u'status': u'Fix Released',
#                                u'tags': [],
#                                u'title': u'Fn::Select no longer accepts integer selector values'}},
#  u'bugs': [u'1245863'],
#  u'change_details': {u'_number': 54321,
#                      u'_sortkey': u'0028c07a0000d431',
#                      u'branch': u'master',
#                      u'change_id': u'I364da88f1c581b406d51e1b584778c7dd4e2564f',
#                      u'created': u'2013-10-29 12:58:45.000000000',
#                      u'id': u'openstack%2Fheat~master~I364da88f1c581b406d51e1b584778c7dd4e2564f',
#                      u'kind': u'gerritcodereview#change',
#                      u'labels': {u'Code-Review': {u'all': [{u'_account_id': 4328,
#                                                             u'name': u'Steven Hardy',
#                                                             u'value': 2},
#                                                            {u'_account_id': 6488,
#                                                             u'name': u"Clint 'SpamapS' Byrum",
#                                                             u'value': 2}],
#                                                   u'approved': {u'_account_id': 4328,
#                                                                 u'name': u'Steven Hardy'}},
#                                  u'Verified': {u'all': [{u'_account_id': 3,
#                                                          u'name': u'Jenkins',
#                                                          u'value': 2}],
#                                                u'approved': {u'_account_id': 3,
#                                                              u'name': u'Jenkins'}},
#                                  u'Workflow': {u'all': [{u'_account_id': 6488,
#                                                          u'name': u"Clint 'SpamapS' Byrum",
#                                                          u'value': 1}],
#                                                u'approved': {u'_account_id': 6488,
#                                                              u'name': u"Clint 'SpamapS' Byrum"}}},
#                      u'messages': [{u'_revision_number': 2,
#                                     u'author': {u'_account_id': 6849,
#                                                 u'avatars': [],
#                                                 u'email': u'rpodolyaka@mirantis.com',
#                                                 u'name': u'Roman Podoliaka',
#                                                 u'username': u'rpodolyaka'},
#                                     u'date': u'2013-10-29 14:25:03.000000000',
#                                     u'id': u'AAAATn//wY8=',
#                                     u'message': u'Uploaded patch set 2.'},
#                                    {u'_revision_number': 2,
#                                     u'author': {u'_account_id': 4328,
#                                                 u'avatars': [],
#                                                 u'email': u'shardy@redhat.com',
#                                                 u'name': u'Steven Hardy',
#                                                 u'username': u'shardy'},
#                                     u'date': u'2013-10-29 14:32:56.000000000',
#                                     u'id': u'AAAATn//wUE=',
#                                     u'message': u'Patch Set 2: Looks good to me (core reviewer)\n\n'},
#                                    {u'_revision_number': 2,
#                                     u'author': {u'_account_id': 3,
#                                                 u'avatars': [],
#                                                 u'name': u'Jenkins',
#                                                 u'username': u'jenkins'},
#                                     u'date': u'2013-10-29 14:57:43.000000000',
#                                     u'id': u'AAAATn//wLo=',
#                                     u'message': u'Patch Set 2: Works for me\n\nBuild succeeded.\n\n- gate-heat-pep8 http://logs.openstack.org/21/54321/2/check/gate-heat-pep8/fa56035 : SUCCESS in 2m 06s\n- gate-heat-docs http://docs-draft.openstack.org/21/54321/2/check/gate-heat-docs/0d3b9d2/doc/build/html/ : SUCCESS in 3m 05s\n- gate-heat-python26 http://logs.openstack.org/21/54321/2/check/gate-heat-python26/0bb791d : SUCCESS in 3m 05s\n- gate-heat-python27 http://logs.openstack.org/21/54321/2/check/gate-heat-python27/7a9d2aa : SUCCESS in 2m 57s\n- check-tempest-devstack-vm-full http://logs.openstack.org/21/54321/2/check/check-tempest-devstack-vm-full/9837a3e : SUCCESS in 31m 50s\n- check-tempest-devstack-vm-postgres-full http://logs.openstack.org/21/54321/2/check/check-tempest-devstack-vm-postgres-full/9fc2e10 : SUCCESS in 32m 21s\n- check-tempest-devstack-vm-neutron http://logs.openstack.org/21/54321/2/check/check-tempest-devstack-vm-neutron/69ab9a3 : SUCCESS in 20m 32s\n- gate-tempest-devstack-vm-large-ops http://logs.openstack.org/21/54321/2/check/gate-tempest-devstack-vm-large-ops/65bf30b : SUCCESS in 14m 35s\n- gate-tempest-devstack-vm-neutron-large-ops http://logs.openstack.org/21/54321/2/check/gate-tempest-devstack-vm-neutron-large-ops/155150f : SUCCESS in 16m 46s (non-voting)\n'},
#                                    {u'_revision_number': 2,
#                                     u'author': {u'_account_id': 6488,
#                                                 u'avatars': [],
#                                                 u'email': u'clint@fewbar.com',
#                                                 u'name': u"Clint 'SpamapS' Byrum",
#                                                 u'username': u'clint-fewbar'},
#                                     u'date': u'2013-10-29 15:17:39.000000000',
#                                     u'id': u'AAAATn//wBc=',
#                                     u'message': u'Patch Set 2: Looks good to me (core reviewer); Approved\n\nSo embarrassing to have missed that regression. Thanks for the fix Roman!!'},
#                                    {u'_revision_number': 2,
#                                     u'author': {u'_account_id': 3,
#                                                 u'avatars': [],
#                                                 u'name': u'Jenkins',
#                                                 u'username': u'jenkins'},
#                                     u'date': u'2013-10-29 15:18:11.000000000',
#                                     u'id': u'AAAATn//wA8=',
#                                     u'message': u'Patch Set 2: No score\n\nStarting gate jobs.\nhttp://status.openstack.org/zuul/'},
#                                    {u'_revision_number': 2,
#                                     u'author': {u'_account_id': 3,
#                                                 u'avatars': [],
#                                                 u'name': u'Jenkins',
#                                                 u'username': u'jenkins'},
#                                     u'date': u'2013-10-29 15:54:42.000000000',
#                                     u'id': u'AAAATn//vwI=',
#                                     u'message': u'Patch Set 2: Verified\n\nBuild succeeded.\n\n- gate-heat-pep8 http://logs.openstack.org/21/54321/2/gate/gate-heat-pep8/e4d0c0c : SUCCESS in 2m 41s\n- gate-heat-docs http://docs-draft.openstack.org/21/54321/2/gate/gate-heat-docs/100fe22/doc/build/html/ : SUCCESS in 2m 05s\n- gate-heat-python26 http://logs.openstack.org/21/54321/2/gate/gate-heat-python26/87f5033 : SUCCESS in 3m 15s\n- gate-heat-python27 http://logs.openstack.org/21/54321/2/gate/gate-heat-python27/e353211 : SUCCESS in 2m 58s\n- gate-tempest-devstack-vm-full http://logs.openstack.org/21/54321/2/gate/gate-tempest-devstack-vm-full/98f8c73 : SUCCESS in 34m 24s\n- gate-tempest-devstack-vm-postgres-full http://logs.openstack.org/21/54321/2/gate/gate-tempest-devstack-vm-postgres-full/6cc4782 : SUCCESS in 31m 14s\n- gate-tempest-devstack-vm-neutron http://logs.openstack.org/21/54321/2/gate/gate-tempest-devstack-vm-neutron/e6cf68e : SUCCESS in 19m 01s\n- gate-tempest-devstack-vm-large-ops http://logs.openstack.org/21/54321/2/gate/gate-tempest-devstack-vm-large-ops/a678ef4 : SUCCESS in 17m 39s\n- gate-tempest-devstack-vm-neutron-large-ops http://logs.openstack.org/21/54321/2/gate/gate-tempest-devstack-vm-neutron-large-ops/fb27a63 : SUCCESS in 17m 39s (non-voting)\n'},
#                                    {u'_revision_number': 2,
#                                     u'author': {u'_account_id': 3,
#                                                 u'avatars': [],
#                                                 u'name': u'Jenkins',
#                                                 u'username': u'jenkins'},
#                                     u'date': u'2013-10-29 15:54:43.000000000',
#                                     u'id': u'AAAATn//vwE=',
#                                     u'message': u'Change has been successfully merged into the git repository.'}],
#                      u'owner': {u'_account_id': 6849,
#                                 u'name': u'Roman Podoliaka'},
#                      u'project': u'openstack/heat',
#                      u'status': u'MERGED',
#                      u'subject': u'Make Fn::Select accept an integer selector again',
#                      u'topic': u'bug/1245863',
#                      u'updated': u'2013-10-29 15:54:43.000000000'},
#  u'change_id': u'I364da88f1c581b406d51e1b584778c7dd4e2564f',
#  u'children': [u'12a23a804e87f019758a32594629dc65755efe26',
#                u'3dead2a0811d83b701ad2d9aac9713b2f426d256'],
#  u'cid': u'11ac4dd3f899dc0f28d356bad89ec559e9d1e81f',
#  u'committer': u'<git.Actor "Roman Podoliaka <rpodolyaka@mirantis.com>">',
#  u'date': 1383054567,
#  u'distance_from_mainline': 0,
#  'file_order': {u'heat/engine/template.py': 27},
#  'file_order_for_author': {u'heat/engine/template.py': 1},
#  u'files': [u'heat/engine/template.py'],
#  'guilt': 0.0,
#  u'is_master_commit': False,
#  'is_tracked_change': True,
#  'loc_add': 4,
#  'loc_change': 4,
#  'loc_detail': {u'heat/engine/template.py': {u'add': 4, u'changes': 4}},
#  u'msg': u'Make Fn::Select accept an integer selector again\n\nCloses-Bug: #1245863\n\nChange-Id: I364da88f1c581b406d51e1b584778c7dd4e2564f\n',
#  u'on_mainline': True,
#  u'on_master_branch': True,
#  'order': 1376,
#  u'parents': [u'614e196f01d1e675d7e512bdc66de10a3a8c8e40'],
#  'reachable': True,
#  'tagged_bug_fix': True,
#  u'unfiltered_files': [u'heat/engine/template.py',
#                        u'heat/tests/test_parser.py']}

# %% [markdown]
# #Features

# %%
legacy_cutoff = find_legacy_cutoff(combined_commits)
min_order, max_order = get_commit_ordering_min_max(combined_commits)
actual_bugs = compute_selected_bug_fixes(combined_commits,
                                             legacy_cutoff=legacy_cutoff,
                                             min_order=min_order,
                                             max_order=max_order)
guilt_threshold, labeled_bugs = autoset_threshold(combined_commits,
                                                      actual_bugs)
extract_state = fit_features(combined_commits, min_order=min_order,
                                 max_order=max_order)
# Out:
#   Total Alias: 37
# Total features: 2374

# %% [markdown]
# ###### Note:  Ordinarily one would not call extract_features_helper directly, but calling to expose raw feature fectors

# %%
cid, Y, features = extract_features_helper(combined_commits,
                                               min_order, max_order,
                                               0, 0,
                                               **extract_state['feat_kwargs'])
# Out:
#   Total Alias: 37

# %% [markdown]
# ###### Sample Feature Vector - for input to Scikit-Learn scaler and DictVectorizer

# %%
features[0]
# Out:
# {'author': u'sbaker@redhat.com',
#  'author_order': 3.2188758248682006,
#  'author_org': u'redhat.com',
#  'blueprint': True,
#  'cherry_picked_from': False,
#  'cherry_picked_to': False,
#  'committer': 'same',
#  'gerrit_approved_code': u'Angus Salkeld',
#  'gerrit_approved_workflow': u'Angus Salkeld',
#  'gerrit_has_data': True,
#  u'gerrit_reviewer_Angus Salkeld': 2,
#  'gerrit_revision': 1,
#  'gerrit_votes': 2,
#  u'includes_file_heat/engine/identifier.py': 1,
#  u'includes_file_heat/engine/service.py': 1,
#  'lauchpad_bugs': 0,
#  'loc_add': 2,
#  u'loc_add_heat/engine/identifier.py': 0,
#  u'loc_add_heat/engine/service.py': 2,
#  'loc_change': 15,
#  u'loc_changes_heat/engine/identifier.py': 10,
#  u'loc_changes_heat/engine/service.py': 5,
#  'log_max_file_order': 1.3862943611198906,
#  'log_min_file_order': 1.3862943611198906,
#  'log_order': 5.958424693029782}

# %% [markdown]
# ### Generation of data for use with Scikit-Learn

# %%
all_cid, Y, X, col_names = extract_features(combined_commits,
                                                extract_state,
                                                min_order=min_order,
                                                max_order=max_order,
                                                threshold=guilt_threshold)
# Out:
#   Total Alias: 37
# Total feature vectors: 2586
#   bugs based on threshold: 703

# %% [markdown]
# ###### Commit ID corresponsing to each feature vector

# %%
all_cid[:10]
# Out:
# (u'89caca42d693a686fc190bfd9e35606b4a21f208',
#  u'9096b586e2246cbc13b13141216a775720770c80',
#  u'bc2c6dbcfe097b45f53b162f6433e6fdd2ca9fa7',
#  u'a425ae02af7a25aa3654e644dc966d07f408a60c',
#  u'ba00a025d4a5b72638a002ce4e123f6e824d9aa9',
#  u'40ed0ade378bb0289c546e7c2cc16891275c3e2b',
#  u'bd8edd25fa8423ded878b4f3d0d0403e64c3cd17',
#  u'2622c2ac4ecfc499f947d749b76ea1538148d4bb',
#  u'27c5ea86f3c888be909788e40688624cc9b71b10',
#  u'ad1e45573ece5bb5ca5d6b2273d0d3ab8faba806')

# %% [markdown]
# ###### Labels for each feature vector

# %%
Y
# Out:
# array([ True, False,  True, ..., False, False, False], dtype=bool)

# %% [markdown]
# ###### Matrix of Feature Vetors, on row per commit

# %%
X
# Out:
# array([[ 0.        ,  0.        ,  0.        , ...,  0.24982436,
#          0.25143961,  0.        ],
#        [ 0.        ,  0.        ,  0.        , ...,  0.35067282,
#          0.1257198 ,  0.00126591],
#        [ 0.        ,  0.        ,  0.        , ...,  0.64578659,
#          0.29191234,  0.00252857],
#        ...,
#        [ 0.        ,  0.        ,  0.        , ...,  0.24982436,
#          0.1257198 ,  0.99966978],
#        [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#          0.        ,  0.99983492],
#        [ 0.        ,  0.        ,  0.        , ...,  0.80686167,
#          0.        ,  1.        ]])

# %% [markdown]
# ###### Column Heading for feature matrix

# %%
col_names
# Out:
# [u'author=Niu.ZGlinux@gmail.com',
#  u'author=achudnovets@mirantis.com',
#  u'author=adrien.verge@numergy.com',
#  u'author=agordeev@mirantis.com',
#  u'author=aigerim.sametkhanova@gmail.com',
#  u'author=aignatov@mirantis.com',
#  u'author=aivanitskiy@mirantis.com',
#  u'author=aj@suse.de',
#  u'author=akurilin@mirantis.com',
#  u'author=akuznetsova@mirantis.com',
#  u'author=alex.gaynor@gmail.com',
#  u'author=amagarw3@cisco.com',
#  u'author=anant.patil@hp.com',
#  u'author=andersonvom@gmail.com',
#  u'author=andrea.rosa@hp.com',
#  u'author=andrew.plunk@rackspace.com',
#  u'author=apevec@redhat.com',
#  u'author=asalkeld@mirantis.com',
#  u'author=barnold@us.ibm.com',
#  u'author=bartosz.gorski@ntti3.com',
#  u'author=berendt@b1-systems.de',
#  u'author=bk@theboxes.org',
#  u'author=bknudson@us.ibm.com',
#  u'author=bnemec@redhat.com',
#  u'author=bwiedemann@suse.de',
#  u'author=cbjchen@cn.ibm.com',
#  u'author=chenxiao@cn.ibm.com',
#  u'author=chmouel@enovance.com',
#  u'author=chris.armstrong@rackspace.com',
#  u'author=chrisroberts.code@gmail.com',
#  u'author=chuck.short@canonical.com',
#  u'author=clint@fewbar.com',
#  u'author=cody.somerville@hp.com',
#  u'author=daniel.givens@rackspace.com',
#  u'author=daniel@gonzalez-nothnagel.de',
#  u'author=denny@unitedstack.com',
#  u'author=derekh@redhat.com',
#  u'author=dimitri.mazmanov@ericsson.com',
#  u'author=dims@linux.vnet.ibm.com',
#  u'author=dinghaiyang@huawei.com',
#  u'author=dirk@dmllr.de',
#  u'author=dongbing.lv@kylin-cloud.com',
#  u'author=doug@doughellmann.com',
#  u'author=dprince@redhat.com',
#  u'author=drago@rosson.me',
#  u'author=drfish@us.ibm.com',
#  u'author=eglynn@redhat.com',
#  u'author=ekudryashova@mirantis.com',
#  u'author=emilien.macchi@enovance.com',
#  u'author=endre.karlson@gmail.com',
#  u'author=fabien.boucher@enovance.com',
#  u'author=gauvain.pocentek@objectif-libre.com',
#  u'author=george.peristerakis@enovance.com',
#  u'author=gerrit@highbridgellc.com',
#  u'author=gfidente@redhat.com',
#  u'author=greg@greghaynes.net',
#  u'author=guohliu@cn.ibm.com',
#  u'author=hongbin034@gmail.com',
#  u'author=honjo.rikimaru@po.ntts.co.jp',
#  u'author=huangtianhua@huawei.com',
#  u'author=huruifeng@huawei.com',
#  u'author=iartarisi@suse.cz',
#  u'author=imain@redhat.com',
#  u'author=imcleod@redhat.com',
#  u'author=ishant.tyagi@hp.com',
#  u'author=j.rosenboom@x-ion.de',
#  u'author=jamielennox@redhat.com',
#  u'author=jason.dobies@redhat.com',
#  u'author=jasondunsmore@gmail.com',
#  u'author=jenkins@openstack.org',
#  u'author=jenkins@review.openstack.org',
#  u'author=jiangfeihu@huawei.com',
#  u'author=jiangyaoguo@huawei.com',
#  u'author=jianingy@unitedstack.com',
#  u'author=jordan.pittier-ext@cloudwatt.com',
#  u'author=jpeeler@redhat.com',
#  u'author=jprovazn@redhat.com',
#  u'author=julien@danjou.info',
#  u'author=junxiebj@cn.ibm.com',
#  u'author=jvarlamova@mirantis.com',
#  u'author=kanabuchi.mitsuru@po.ntts.co.jp',
#  u'author=kanagaraj.manickam@hp.com',
#  u'author=kevin@efox.cc',
#  u'author=kkushaev@mirantis.com',
#  u'author=lars@redhat.com',
#  u'author=lhh@redhat.com',
#  u'author=lin.tan@intel.com',
#  u'author=lisongbj@cn.ibm.com',
#  u'author=liugya@cn.ibm.com',
#  u'author=liusheng@huawei.com',
#  u'author=lizheming.li@huawei.com',
#  u'author=luis@linux.vnet.ibm.com',
#  u'author=markmc@redhat.com',
#  u'author=martin@geisler.net',
#  u'author=matt@jones-central.net',
#  u'author=miguel.grinberg@gmail.com',
#  u'author=mikal@stillhq.com',
#  u'author=miki.ryo@po.ntts.co.jp',
#  u'author=mordred@inaugust.com',
#  u'author=morgan.fainberg@gmail.com',
#  u'author=mriedem@us.ibm.com',
#  u'author=mspreitz@us.ibm.com',
#  u'author=nanjj@cn.ibm.com',
#  u'author=natsume.takashi@lab.ntt.co.jp',
#  u'author=neil.zhangyang@huawei.com',
#  u'author=notsu@virtualtech.jp',
#  u'author=ochuprykov@mirantis.com',
#  u'author=openstack-infra@lists.openstack.org',
#  u'author=pablo.a.fuente@intel.com',
#  u'author=philippejeurissen@gmail.com',
#  u'author=pierre.freund@osones.com',
#  u'author=pierre.padrixe@numergy.com',
#  u'author=pratik.mallya@gmail.com',
#  u'author=prazumovsky@mirantis.com',
#  u'author=pshchelokovskyy@mirantis.com',
#  u'author=pvaneck@us.ibm.com',
#  u'author=qizh@cn.ibm.com',
#  u'author=ramishra@redhat.com',
#  u'author=randall.burt@rackspace.com',
#  u'author=rblee88@gmail.com',
#  u'author=rbryant@redhat.com',
#  u'author=rbtcollins@hp.com',
#  u'author=rh-s@hp.com',
#  u'author=rpodolyaka@mirantis.com',
#  u'author=rpothier@cisco.com',
#  u'author=rybrown@redhat.com',
#  u'author=sam.alba@gmail.com',
#  u'author=sbaker@redhat.com',
#  u'author=sdake@redhat.com',
#  u'author=shane.wang@intel.com',
#  u'author=shardy@redhat.com',
#  u'author=sileht@sileht.net',
#  u'author=sirushti.murugesan@hp.com',
#  u'author=skraynev@mirantis.com',
#  u'author=slagun@mirantis.com',
#  u'author=slukjanov@mirantis.com',
#  u'author=smelikyan@mirantis.com',
#  u'author=sneezezhang@cienet.com.cn',
#  u'author=spasquier@mirantis.com',
#  u'author=spzala@us.ibm.com',
#  u'author=sreshetniak@mirantis.com',
#  u'author=sshturm@mirantis.com',
#  u'author=sskripnick@mirantis.com',
#  u'author=sslypushenko@mirantis.com',
#  u'author=stephen.gran@guardian.co.uk',
#  u'author=steven.j.mclellan@gmail.com',
#  u'author=sumitnaiksatam@gmail.com',
#  u'author=sushil.kumar2@globallogic.com',
#  u'author=swann@oopss.org',
#  u'author=taget@linux.vnet.ibm.com',
#  u'author=tengqim@cn.ibm.com',
#  u'author=thomas.herve@enovance.com',
#  u'author=thomas.spatzier@de.ibm.com',
#  u'author=tim.schnell@rackspace.com',
#  u'author=tlashchova@mirantis.com',
#  u'author=tokwii@cisco.com',
#  u'author=tominaga.yoshimi@tis.co.jp',
#  u'author=ton@us.ibm.com',
#  u'author=tsedovic@redhat.com',
#  u'author=tsmith@gridcentric.com',
#  u'author=unmesh.gurjar@hp.com',
#  u'author=victor.r.howard@gmail.com',
#  u'author=vijendar.komalla@RACKSPACE.COM',
#  u'author=vikjain@cisco.com',
#  u'author=vinod.mang@rackspace.com',
#  u'author=visnusaran.murugan@hp.com',
#  u'author=vkuklin@mirantis.com',
#  u'author=vsergeyev@mirantis.com',
#  u'author=willowd878@gmail.com',
#  u'author=winson.c.chan@intel.com',
#  u'author=woodspa@us.ibm.com',
#  u'author=xianghui@cn.ibm.com',
#  u'author=xjunlin@cn.ibm.com',
#  u'author=xu-haiwei@mxw.nes.nec.co.jp',
#  u'author=yanyanhu@cn.ibm.com',
#  u'author=ying.li@rackspace.com',
#  u'author=zbitter@redhat.com',
#  u'author=zhiqiang.fan@huawei.com',
#  u'author=zhuzhubj@cn.ibm.com',
#  'author_order',
#  u'author_org=RACKSPACE.COM',
#  u'author_org=b1-systems.de',
#  u'author_org=bull.net',
#  u'author_org=canonical.com',
#  u'author_org=cienet.com.cn',
#  u'author_org=cisco.com',
#  u'author_org=cloudwatt.com',
#  u'author_org=cn.ibm.com',
#  u'author_org=danjou.info',
#  u'author_org=de.ibm.com',
#  u'author_org=dmllr.de',
#  u'author_org=doughellmann.com',
#  u'author_org=efox.cc',
#  u'author_org=enovance.com',
#  u'author_org=ericsson.com',
#  u'author_org=fewbar.com',
#  u'author_org=geisler.net',
#  u'author_org=globallogic.com',
#  u'author_org=gmail.com',
#  u'author_org=gonzalez-nothnagel.de',
#  u'author_org=greghaynes.net',
#  u'author_org=gridcentric.com',
#  u'author_org=guardian.co.uk',
#  u'author_org=highbridgellc.com',
#  u'author_org=hp.com',
#  u'author_org=huawei.com',
#  u'author_org=inaugust.com',
#  u'author_org=intel.com',
#  u'author_org=jones-central.net',
#  u'author_org=kylin-cloud.com',
#  u'author_org=lab.ntt.co.jp',
#  u'author_org=linux.vnet.ibm.com',
#  u'author_org=lists.openstack.org',
#  u'author_org=mirantis.com',
#  u'author_org=mxw.nes.nec.co.jp',
#  u'author_org=nemebean.com',
#  u'author_org=ntti3.com',
#  u'author_org=numergy.com',
#  u'author_org=objectif-libre.com',
#  u'author_org=oopss.org',
#  u'author_org=openstack.org',
#  u'author_org=osones.com',
#  u'author_org=po.ntts.co.jp',
#  u'author_org=rackspace.com',
#  u'author_org=redhat.com',
#  u'author_org=review.openstack.org',
#  u'author_org=rosson.me',
#  u'author_org=salkeld.id.au',
#  u'author_org=sedovic.cz',
#  u'author_org=sileht.net',
#  u'author_org=stillhq.com',
#  u'author_org=suse.cz',
#  u'author_org=suse.de',
#  u'author_org=theboxes.org',
#  u'author_org=tis.co.jp',
#  u'author_org=unitedstack.com',
#  u'author_org=us.ibm.com',
#  u'author_org=virtualtech.jp',
#  u'author_org=x-ion.de',
#  'blueprint',
#  'cherry_picked_from',
#  'cherry_picked_to',
#  u'committer=Niu.ZGlinux@gmail.com',
#  u'committer=andersonvom@gmail.com',
#  u'committer=asalkeld@mirantis.com',
#  u'committer=bartosz.gorski@ntti3.com',
#  u'committer=boris@pavlovic.me',
#  u'committer=clint@fewbar.com',
#  u'committer=dborodaenko@mirantis.com',
#  u'committer=fungi@yuggoth.org',
#  u'committer=jasondunsmore@gmail.com',
#  u'committer=jpeeler@redhat.com',
#  u'committer=luis@linux.vnet.ibm.com',
#  u'committer=mordred@inaugust.com',
#  u'committer=mriedem@us.ibm.com',
#  u'committer=nanjj@cn.ibm.com',
#  u'committer=pratik.mallya@gmail.com',
#  u'committer=pshchelokovskyy@mirantis.com',
#  u'committer=randall.burt@rackspace.com',
#  u'committer=rblee88@gmail.com',
#  u'committer=review@openstack.org',
#  u'committer=rh-s@hp.com',
#  'committer=same',
#  u'committer=sbaker@redhat.com',
#  u'committer=sean@dague.net',
#  u'committer=shardy@redhat.com',
#  u'committer=skraynev@mirantis.com',
#  u'committer=sshturm@mirantis.com',
#  u'committer=steven.j.mclellan@gmail.com',
#  u'committer=tengqim@cn.ibm.com',
#  u'committer=thomas.herve@enovance.com',
#  u'committer=thomas.spatzier@de.ibm.com',
#  u'committer=tlashchova@mirantis.com',
#  u'committer=xjunlin@cn.ibm.com',
#  u'committer=zbitter@redhat.com',
#  u'gerrit_approved_code=Angus Salkeld',
#  u'gerrit_approved_code=Bartosz G\xf3rski',
#  u"gerrit_approved_code=Clint 'SpamapS' Byrum",
#  u'gerrit_approved_code=Jason Dunsmore',
#  u'gerrit_approved_code=Jeff Peeler',
#  u'gerrit_approved_code=Liang Chen',
#  u'gerrit_approved_code=Pavlo Shchelokovskyy',
#  u'gerrit_approved_code=Qiming Teng',
#  u'gerrit_approved_code=Randall Burt',
#  u'gerrit_approved_code=Sergey Kraynev',
#  u'gerrit_approved_code=Steve Baker',
#  u'gerrit_approved_code=Steven Dake',
#  u'gerrit_approved_code=Steven Hardy',
#  u'gerrit_approved_code=Thomas Herve',
#  u'gerrit_approved_code=Thomas Spatzier',
#  u'gerrit_approved_code=Zane Bitter',
#  u'gerrit_approved_code=huangtianhua',
#  u'gerrit_approved_workflow=Angus Salkeld',
#  u'gerrit_approved_workflow=Bartosz G\xf3rski',
#  u"gerrit_approved_workflow=Clint 'SpamapS' Byrum",
#  u'gerrit_approved_workflow=James E. Blair',
#  u'gerrit_approved_workflow=Jason Dunsmore',
#  u'gerrit_approved_workflow=Jeff Peeler',
#  u'gerrit_approved_workflow=Liang Chen',
#  u'gerrit_approved_workflow=Pavlo Shchelokovskyy',
#  u'gerrit_approved_workflow=Qiming Teng',
#  u'gerrit_approved_workflow=Randall Burt',
#  u'gerrit_approved_workflow=Sergey Kraynev',
#  u'gerrit_approved_workflow=Steve Baker',
#  u'gerrit_approved_workflow=Steven Dake',
#  u'gerrit_approved_workflow=Steven Hardy',
#  u'gerrit_approved_workflow=Thomas Herve',
#  u'gerrit_approved_workflow=Thomas Spatzier',
#  u'gerrit_approved_workflow=Zane Bitter',
#  u'gerrit_approved_workflow=huangtianhua',
#  u'gerrit_approved_workflow=imain',
#  'gerrit_has_data',
#  u'gerrit_reviewer_Adrien Verg\xe9',
#  u'gerrit_reviewer_Alexander Ignatov',
#  u'gerrit_reviewer_Anant Patil',
#  u'gerrit_reviewer_Anastasia Guzikova',
#  u'gerrit_reviewer_Anastasia Kuznetsova',
#  u'gerrit_reviewer_Anderson Mesquita',
#  u'gerrit_reviewer_Andre Aranha',
#  u'gerrit_reviewer_Andrea Frittoli ',
#  u'gerrit_reviewer_Andrea Rosa',
#  u'gerrit_reviewer_Andreas Jaeger',
#  u'gerrit_reviewer_Andres Buraschi',
#  u'gerrit_reviewer_Andrew Lazarev',
#  u'gerrit_reviewer_Andrew Plunk',
#  u'gerrit_reviewer_Andrey Alekov',
#  u'gerrit_reviewer_Angus Salkeld',
#  u'gerrit_reviewer_Ashraf Vazeer',
#  u'gerrit_reviewer_BK Box',
#  u'gerrit_reviewer_Bartosz G\xf3rski',
#  u'gerrit_reviewer_Ben Nemec',
#  u'gerrit_reviewer_Bogdan Dobrelya',
#  u'gerrit_reviewer_Boris Pavlovic',
#  u'gerrit_reviewer_Chmouel Boudjnah',
#  u'gerrit_reviewer_Christian Berendt',
#  u'gerrit_reviewer_Christopher Armstrong',
#  u"gerrit_reviewer_Clint 'SpamapS' Byrum",
#  u'gerrit_reviewer_Daniel Gonzalez Nothnagel',
#  u'gerrit_reviewer_Davanum Srinivas (dims)',
#  u'gerrit_reviewer_David Geng',
#  u'gerrit_reviewer_Deliang Fan',
#  u'gerrit_reviewer_Denis M.',
#  u'gerrit_reviewer_DennyZhang',
#  u'gerrit_reviewer_Derek Higgins',
#  u'gerrit_reviewer_Dimitri Mazmanov',
#  u'gerrit_reviewer_Dina Belova',
#  u'gerrit_reviewer_Divakar Padiyar Nandavar',
#  u'gerrit_reviewer_Dong Liu',
#  u'gerrit_reviewer_Doug Hellmann',
#  u'gerrit_reviewer_Dougal Matthews',
#  u'gerrit_reviewer_Emilio Recio',
#  u'gerrit_reviewer_Eoghan Glynn',
#  u'gerrit_reviewer_Eric Windisch',
#  u'gerrit_reviewer_Espartaco Palma',
#  u'gerrit_reviewer_Ethan Lynn',
#  u'gerrit_reviewer_Flavio Percoco',
#  u'gerrit_reviewer_Florent Flament',
#  u'gerrit_reviewer_Gael Chamoulaud',
#  u'gerrit_reviewer_GuoHui LIu',
#  u'gerrit_reviewer_Hai Ming Yang',
#  u'gerrit_reviewer_Haiyang DING',
#  u'gerrit_reviewer_Huruifeng',
#  u'gerrit_reviewer_Ian Cordasco',
#  u'gerrit_reviewer_Ian Wienand',
#  u'gerrit_reviewer_Ilya Sviridov',
#  u'gerrit_reviewer_Imre Farkas',
#  u'gerrit_reviewer_Ishant Tyagi',
#  u'gerrit_reviewer_James Carey',
#  u'gerrit_reviewer_Jan Provaznik',
#  u'gerrit_reviewer_Jason Dunsmore',
#  u'gerrit_reviewer_Jay Bryant',
#  u'gerrit_reviewer_Jay Dobies',
#  u'gerrit_reviewer_Jay Lau',
#  u'gerrit_reviewer_Jeff Peeler',
#  u'gerrit_reviewer_Jeff Sloyer',
#  u'gerrit_reviewer_Jianing Yang',
#  u'gerrit_reviewer_JimJiang',
#  u'gerrit_reviewer_John Wood',
#  u'gerrit_reviewer_Jonathan Brownell',
#  u'gerrit_reviewer_Joshua Harlow',
#  u'gerrit_reviewer_Joshua Hesketh',
#  u'gerrit_reviewer_Julie Pichon',
#  u'gerrit_reviewer_Julien Danjou',
#  u'gerrit_reviewer_Jun Jie Nan',
#  u'gerrit_reviewer_Jyoti',
#  u'gerrit_reviewer_Kallebe Monteiro',
#  u'gerrit_reviewer_Kanagaraj Manickam',
#  u'gerrit_reviewer_Kashyap Kopparam',
#  u'gerrit_reviewer_Ken Wronkiewicz',
#  u'gerrit_reviewer_Kevin Fox',
#  u'gerrit_reviewer_Kieran Spear',
#  u'gerrit_reviewer_Kiran Kumar Vaddi',
#  u'gerrit_reviewer_Kiyohiro Adachi',
#  u'gerrit_reviewer_Kui Shi',
#  u'gerrit_reviewer_Ladislav Smola',
#  u'gerrit_reviewer_Leandro Ignacio Costantino',
#  u'gerrit_reviewer_Lei Zhang',
#  u'gerrit_reviewer_Li Yingjun',
#  u'gerrit_reviewer_Liang Chen',
#  u'gerrit_reviewer_Lingxian Kong',
#  u'gerrit_reviewer_Mahalakshmi Balakrishnan',
#  u'gerrit_reviewer_Matthew Gilliard',
#  u'gerrit_reviewer_Matthew Oliver',
#  u'gerrit_reviewer_Michael Elder',
#  u'gerrit_reviewer_Michal Jastrzebski (inc0)',
#  u'gerrit_reviewer_Miguel Grinberg',
#  u'gerrit_reviewer_Mike Spreitzer',
#  u'gerrit_reviewer_Mitsuru Kanabuchi',
#  u'gerrit_reviewer_Mohit Sethi',
#  u'gerrit_reviewer_Neela Shah',
#  u'gerrit_reviewer_Nicholas Randon',
#  u'gerrit_reviewer_Nikhil Manchanda',
#  u'gerrit_reviewer_Nikunj Aggarwal',
#  u'gerrit_reviewer_Pablo Andres Fuente',
#  u'gerrit_reviewer_Patrick Woods',
#  u'gerrit_reviewer_Paul Nelson',
#  u'gerrit_reviewer_Paul Van Eck',
#  u'gerrit_reviewer_Pavlo Shchelokovskyy',
#  u'gerrit_reviewer_Peter Razumovsky',
#  u'gerrit_reviewer_Petr Cech',
#  u'gerrit_reviewer_Pierre Padrixe (stannie)',
#  u'gerrit_reviewer_Pradeep Kumar Chandani',
#  u'gerrit_reviewer_Qiming Teng',
#  u'gerrit_reviewer_Rabi Mishra',
#  u'gerrit_reviewer_Rakesh H S',
#  u'gerrit_reviewer_Randall Burt',
#  u'gerrit_reviewer_Richard Lee',
#  u'gerrit_reviewer_Rob Pothier',
#  u'gerrit_reviewer_Robert Mizielski',
#  u'gerrit_reviewer_Roman Bogorodskiy',
#  u'gerrit_reviewer_Roman Podoliaka',
#  u'gerrit_reviewer_Rui Chen',
#  u'gerrit_reviewer_Ryan Brady',
#  u'gerrit_reviewer_Ryan Brown',
#  u'gerrit_reviewer_Sahdev Zala',
#  u'gerrit_reviewer_Sam Harwell',
#  u'gerrit_reviewer_Sarvesh Ranjan',
#  u'gerrit_reviewer_Sean Dague',
#  u'gerrit_reviewer_Sean M. Collins',
#  u'gerrit_reviewer_Serg Melikyan',
#  u'gerrit_reviewer_Sergey Kraynev',
#  u'gerrit_reviewer_Sergey Lukjanov',
#  u'gerrit_reviewer_Sergey Reshetnyak',
#  u'gerrit_reviewer_Sergey Vasilenko',
#  u'gerrit_reviewer_Shilla Saebi',
#  u'gerrit_reviewer_Simon Pasquier',
#  u'gerrit_reviewer_Sirushti Murugesan',
#  u'gerrit_reviewer_Stephen Gran',
#  u'gerrit_reviewer_Steve Baker',
#  u'gerrit_reviewer_Steve Kowalik',
#  u'gerrit_reviewer_Steve McLellan',
#  u'gerrit_reviewer_Steven Dake',
#  u'gerrit_reviewer_Steven Hardy',
#  u'gerrit_reviewer_Swann Croiset',
#  u'gerrit_reviewer_Takashi NATSUME',
#  u'gerrit_reviewer_Tetiana Lashchova',
#  u'gerrit_reviewer_Thiago Gomes',
#  u'gerrit_reviewer_Thomas Goirand',
#  u'gerrit_reviewer_Thomas Herve',
#  u'gerrit_reviewer_Thomas Spatzier',
#  u'gerrit_reviewer_Tim Schnell',
#  u'gerrit_reviewer_Timur Nurlygayanov',
#  u'gerrit_reviewer_Tomas Sedovic',
#  u'gerrit_reviewer_Tommy V\xe4rre',
#  u'gerrit_reviewer_Ton Ngo',
#  u'gerrit_reviewer_Victor Howard',
#  u'gerrit_reviewer_Victor Sergeyev',
#  u'gerrit_reviewer_Victor Stinner',
#  u'gerrit_reviewer_Vijendar Komalla',
#  u'gerrit_reviewer_Visnusaran Murugan',
#  u'gerrit_reviewer_William C. Arnold',
#  u'gerrit_reviewer_Winnie Tsang',
#  u'gerrit_reviewer_YangLei',
#  u'gerrit_reviewer_Yanyan Hu',
#  u'gerrit_reviewer_Yaoguo Jiang',
#  u'gerrit_reviewer_Yaroslav Lobankov',
#  u'gerrit_reviewer_Yathiraj Udupi',
#  u'gerrit_reviewer_Ying Li',
#  u'gerrit_reviewer_Yogesh',
#  u'gerrit_reviewer_Yu Zhang',
#  u'gerrit_reviewer_Zane Bitter',
#  u'gerrit_reviewer_Zhang Yang',
#  u'gerrit_reviewer_Zhenguo Niu',
#  u'gerrit_reviewer_ZhiQiang Fan',
#  u'gerrit_reviewer_Zhu Zhu',
#  u'gerrit_reviewer_abhiram moturi',
#  u'gerrit_reviewer_amagarw3',
#  u'gerrit_reviewer_bryan-murray',
#  u'gerrit_reviewer_frazy',
#  u'gerrit_reviewer_greghaynes',
#  u'gerrit_reviewer_huangtianhua',
#  u'gerrit_reviewer_ice yao',
#  u'gerrit_reviewer_imain',
#  u'gerrit_reviewer_jichenjc',
#  u'gerrit_reviewer_keith-bray',
#  u'gerrit_reviewer_lifeless',
#  u'gerrit_reviewer_ling-yun',
#  u'gerrit_reviewer_liusheng',
#  u'gerrit_reviewer_pritesh',
#  u'gerrit_reviewer_sahid',
#  u'gerrit_reviewer_sajuptpm',
#  u'gerrit_reviewer_shihanzhang',
#  u'gerrit_reviewer_shivam shukla',
#  u'gerrit_reviewer_unmesh-gurjar',
#  u'gerrit_reviewer_wanghao',
#  u'gerrit_reviewer_wingwj',
#  u'gerrit_reviewer_xiejunan',
#  u'gerrit_reviewer_xing-yang',
#  u'gerrit_reviewer_xu-haiwei',
#  u'gerrit_reviewer_yangxurong',
#  u'gerrit_reviewer_yapeng Yang',
#  'gerrit_revision',
#  'gerrit_votes',
#  u'includes_file_contrib/barbican/barbican/__init__.py',
#  u'includes_file_contrib/barbican/barbican/clients.py',
#  u'includes_file_contrib/barbican/barbican/resources/__init__.py',
#  u'includes_file_contrib/barbican/barbican/resources/order.py',
#  u'includes_file_contrib/barbican/barbican/resources/secret.py',
#  u'includes_file_contrib/barbican/barbican/tests/__init__.py',
#  u'includes_file_contrib/barbican/barbican/tests/test_clients.py',
#  u'includes_file_contrib/barbican/barbican/tests/test_order.py',
#  u'includes_file_contrib/barbican/barbican/tests/test_secret.py',
#  u'includes_file_contrib/barbican/setup.py',
#  u'includes_file_contrib/bin/run_tests.py',
#  u'includes_file_contrib/cinder_volume_type/cinder_volume_type/__init__.py',
#  u'includes_file_contrib/cinder_volume_type/cinder_volume_type/resources/__init__.py',
#  u'includes_file_contrib/cinder_volume_type/cinder_volume_type/resources/cinder_volume_type.py',
#  u'includes_file_contrib/cinder_volume_type/cinder_volume_type/tests/__init__.py',
#  u'includes_file_contrib/cinder_volume_type/cinder_volume_type/tests/test_cinder_volume_type.py',
#  u'includes_file_contrib/cinder_volume_type/setup.py',
#  u'includes_file_contrib/docker-plugin/__init__.py',
#  u'includes_file_contrib/docker-plugin/plugin/__init__.py',
#  u'includes_file_contrib/docker-plugin/plugin/docker_container.py',
#  u'includes_file_contrib/docker-plugin/tests/__init__.py',
#  u'includes_file_contrib/docker-plugin/tests/fake_docker_client.py',
#  u'includes_file_contrib/docker-plugin/tests/test_docker_container.py',
#  u'includes_file_contrib/docker/docker/resources/docker_container.py',
#  u'includes_file_contrib/docker/docker/tests/fake_docker_client.py',
#  u'includes_file_contrib/docker/docker/tests/test_docker_container.py',
#  u'includes_file_contrib/docker/resources/docker_container.py',
#  u'includes_file_contrib/docker/setup.py',
#  u'includes_file_contrib/docker/tests/test_docker_container.py',
#  u'includes_file_contrib/extraroute/extraroute/__init__.py',
#  u'includes_file_contrib/extraroute/extraroute/resources/__init__.py',
#  u'includes_file_contrib/extraroute/extraroute/resources/extraroute.py',
#  u'includes_file_contrib/extraroute/extraroute/tests/__init__.py',
#  u'includes_file_contrib/extraroute/extraroute/tests/test_extraroute.py',
#  u'includes_file_contrib/extraroute/setup.py',
#  u'includes_file_contrib/heat_barbican/heat_barbican/client.py',
#  u'includes_file_contrib/heat_barbican/heat_barbican/resources/order.py',
#  u'includes_file_contrib/heat_barbican/heat_barbican/resources/secret.py',
#  u'includes_file_contrib/heat_barbican/heat_barbican/tests/test_order.py',
#  u'includes_file_contrib/heat_barbican/heat_barbican/tests/test_secret.py',
#  u'includes_file_contrib/heat_docker/heat_docker/resources/docker_container.py',
#  u'includes_file_contrib/heat_docker/heat_docker/tests/test_docker_container.py',
#  u'includes_file_contrib/heat_gnocchi/heat_gnocchi/__init__.py',
#  u'includes_file_contrib/heat_gnocchi/heat_gnocchi/resources/__init__.py',
#  u'includes_file_contrib/heat_gnocchi/heat_gnocchi/resources/gnocchi_alarm.py',
#  u'includes_file_contrib/heat_gnocchi/heat_gnocchi/tests/__init__.py',
#  u'includes_file_contrib/heat_gnocchi/heat_gnocchi/tests/test_gnocchi_alarm.py',
#  u'includes_file_contrib/heat_gnocchi/setup.py',
#  u'includes_file_contrib/heat_keystone/heat_keystone/__init__.py',
#  u'includes_file_contrib/heat_keystone/heat_keystone/client.py',
#  u'includes_file_contrib/heat_keystone/heat_keystone/exceptions.py',
#  u'includes_file_contrib/heat_keystone/heat_keystone/resources/__init__.py',
#  u'includes_file_contrib/heat_keystone/heat_keystone/resources/role.py',
#  u'includes_file_contrib/heat_keystone/heat_keystone/tests/__init__.py',
#  u'includes_file_contrib/heat_keystone/heat_keystone/tests/test_client.py',
#  u'includes_file_contrib/heat_keystone/heat_keystone/tests/test_role.py',
#  u'includes_file_contrib/heat_keystone/setup.py',
#  u'includes_file_contrib/heat_keystoneclient_v2/heat_keystoneclient_v2/__init__.py',
#  u'includes_file_contrib/heat_keystoneclient_v2/heat_keystoneclient_v2/client.py',
#  u'includes_file_contrib/heat_keystoneclient_v2/heat_keystoneclient_v2/tests/__init__.py',
#  u'includes_file_contrib/heat_keystoneclient_v2/heat_keystoneclient_v2/tests/test_client.py',
#  u'includes_file_contrib/heat_keystoneclient_v2/setup.py',
#  u'includes_file_contrib/heat_marconi/heat_marconi/__init__.py',
#  u'includes_file_contrib/heat_marconi/heat_marconi/client.py',
#  u'includes_file_contrib/heat_marconi/heat_marconi/resources/__init__.py',
#  u'includes_file_contrib/heat_marconi/heat_marconi/resources/queue.py',
#  u'includes_file_contrib/heat_marconi/heat_marconi/tests/__init__.py',
#  u'includes_file_contrib/heat_marconi/heat_marconi/tests/test_queue.py',
#  u'includes_file_contrib/heat_marconi/setup.py',
#  u'includes_file_contrib/heat_mistral/heat_mistral/__init__.py',
#  u'includes_file_contrib/heat_mistral/heat_mistral/client.py',
#  u'includes_file_contrib/heat_mistral/setup.py',
#  u'includes_file_contrib/heat_zaqar/heat_zaqar/client.py',
#  u'includes_file_contrib/heat_zaqar/heat_zaqar/resources/queue.py',
#  u'includes_file_contrib/heat_zaqar/heat_zaqar/tests/test_queue.py',
#  u'includes_file_contrib/marconi-plugin/__init__.py',
#  u'includes_file_contrib/marconi-plugin/plugin/__init__.py',
#  u'includes_file_contrib/marconi-plugin/plugin/queue.py',
#  u'includes_file_contrib/marconi-plugin/tests/__init__.py',
#  u'includes_file_contrib/marconi-plugin/tests/test_queue.py',
#  u'includes_file_contrib/marconi/clients.py',
#  u'includes_file_contrib/marconi/marconi/__init__.py',
#  u'includes_file_contrib/marconi/marconi/clients.py',
#  u'includes_file_contrib/marconi/marconi/resources/__init__.py',
#  u'includes_file_contrib/marconi/marconi/resources/queue.py',
#  u'includes_file_contrib/marconi/marconi/tests/__init__.py',
#  u'includes_file_contrib/marconi/marconi/tests/test_queue.py',
#  u'includes_file_contrib/marconi/plugin/__init__.py',
#  u'includes_file_contrib/marconi/plugin/queue.py',
#  u'includes_file_contrib/marconi/setup.py',
#  u'includes_file_contrib/marconi/tests/test_queue.py',
#  u'includes_file_contrib/nova_flavor/nova_flavor/__init__.py',
#  u'includes_file_contrib/nova_flavor/nova_flavor/resources/__init__.py',
#  u'includes_file_contrib/nova_flavor/nova_flavor/resources/nova_flavor.py',
#  u'includes_file_contrib/nova_flavor/nova_flavor/tests/__init__.py',
#  u'includes_file_contrib/nova_flavor/nova_flavor/tests/test_nova_flavor.py',
#  u'includes_file_contrib/nova_flavor/setup.py',
#  u'includes_file_contrib/rackspace/__init__.py',
#  u'includes_file_contrib/rackspace/clients.py',
#  u'includes_file_contrib/rackspace/heat/__init__.py',
#  u'includes_file_contrib/rackspace/heat/engine/__init__.py',
#  u'includes_file_contrib/rackspace/heat/engine/plugins/__init__.py',
#  u'includes_file_contrib/rackspace/heat/engine/plugins/auto_scale.py',
#  u'includes_file_contrib/rackspace/heat/engine/plugins/clients.py',
#  u'includes_file_contrib/rackspace/heat/engine/plugins/cloud_dns.py',
#  u'includes_file_contrib/rackspace/heat/engine/plugins/cloud_loadbalancer.py',
#  u'includes_file_contrib/rackspace/heat/engine/plugins/cloud_server.py',
#  u'includes_file_contrib/rackspace/heat/engine/plugins/clouddatabase.py',
#  u'includes_file_contrib/rackspace/heat/engine/plugins/rackspace_resource.py',
#  u'includes_file_contrib/rackspace/heat/tests/__init__.py',
#  u'includes_file_contrib/rackspace/heat/tests/test_auto_scale.py',
#  u'includes_file_contrib/rackspace/heat/tests/test_cloud_loadbalancer.py',
#  u'includes_file_contrib/rackspace/heat/tests/test_clouddatabase.py',
#  u'includes_file_contrib/rackspace/heat/tests/test_rackspace_clients.py',
#  u'includes_file_contrib/rackspace/heat/tests/test_rackspace_cloud_server.py',
#  u'includes_file_contrib/rackspace/heat/tests/test_rackspace_dns.py',
#  u'includes_file_contrib/rackspace/rackspace/clients.py',
#  u'includes_file_contrib/rackspace/rackspace/resources/auto_scale.py',
#  u'includes_file_contrib/rackspace/rackspace/resources/cloud_dns.py',
#  u'includes_file_contrib/rackspace/rackspace/resources/cloud_loadbalancer.py',
#  u'includes_file_contrib/rackspace/rackspace/resources/cloud_server.py',
#  u'includes_file_contrib/rackspace/rackspace/resources/cloudnetworks.py',
#  u'includes_file_contrib/rackspace/rackspace/tests/test_auto_scale.py',
#  u'includes_file_contrib/rackspace/rackspace/tests/test_cloud_loadbalancer.py',
#  u'includes_file_contrib/rackspace/rackspace/tests/test_cloudnetworks.py',
#  u'includes_file_contrib/rackspace/rackspace/tests/test_rackspace_clients.py',
#  u'includes_file_contrib/rackspace/rackspace/tests/test_rackspace_cloud_server.py',
#  u'includes_file_contrib/rackspace/rackspace/tests/test_rackspace_dns.py',
#  u'includes_file_contrib/rackspace/resources/auto_scale.py',
#  u'includes_file_contrib/rackspace/resources/cloud_dns.py',
#  u'includes_file_contrib/rackspace/resources/cloud_loadbalancer.py',
#  u'includes_file_contrib/rackspace/resources/cloud_server.py',
#  u'includes_file_contrib/rackspace/resources/cloudnetworks.py',
#  u'includes_file_contrib/rackspace/setup.py',
#  u'includes_file_contrib/rackspace/tests/test_auto_scale.py',
#  u'includes_file_contrib/rackspace/tests/test_cloud_loadbalancer.py',
#  u'includes_file_contrib/rackspace/tests/test_cloudnetworks.py',
#  u'includes_file_contrib/rackspace/tests/test_rackspace_clients.py',
#  u'includes_file_contrib/rackspace/tests/test_rackspace_cloud_server.py',
#  u'includes_file_doc/source/_static/jquery.tweet.js',
#  u'includes_file_doc/source/conf.py',
#  u'includes_file_doc/source/ext/__init__.py',
#  u'includes_file_doc/source/ext/resources.py',
#  u'includes_file_functionaltests/post_test_hook.sh',
#  u'includes_file_functionaltests/pre_test_hook.sh',
#  u'includes_file_heat/__init__.py',
#  u'includes_file_heat/api/__init__.py',
#  u'includes_file_heat/api/aws/ec2token.py',
#  u'includes_file_heat/api/aws/exception.py',
#  u'includes_file_heat/api/aws/utils.py',
#  u'includes_file_heat/api/cfn/__init__.py',
#  u'includes_file_heat/api/cfn/v1/__init__.py',
#  u'includes_file_heat/api/cfn/v1/signal.py',
#  u'includes_file_heat/api/cfn/v1/stacks.py',
#  u'includes_file_heat/api/cfn/v1/waitcondition.py',
#  u'includes_file_heat/api/cfn/versions.py',
#  u'includes_file_heat/api/cloudwatch/__init__.py',
#  u'includes_file_heat/api/cloudwatch/versions.py',
#  u'includes_file_heat/api/cloudwatch/watch.py',
#  u'includes_file_heat/api/middleware/fault.py',
#  u'includes_file_heat/api/middleware/ssl.py',
#  u'includes_file_heat/api/middleware/version_negotiation.py',
#  u'includes_file_heat/api/middleware/x_forwarded_for.py',
#  u'includes_file_heat/api/openstack/__init__.py',
#  u'includes_file_heat/api/openstack/v1/__init__.py',
#  u'includes_file_heat/api/openstack/v1/actions.py',
#  u'includes_file_heat/api/openstack/v1/build_info.py',
#  u'includes_file_heat/api/openstack/v1/events.py',
#  u'includes_file_heat/api/openstack/v1/resources.py',
#  u'includes_file_heat/api/openstack/v1/services.py',
#  u'includes_file_heat/api/openstack/v1/software_configs.py',
#  u'includes_file_heat/api/openstack/v1/software_deployments.py',
#  u'includes_file_heat/api/openstack/v1/stacks.py',
#  u'includes_file_heat/api/openstack/v1/util.py',
#  u'includes_file_heat/api/openstack/v1/views/__init__.py',
#  u'includes_file_heat/api/openstack/v1/views/stacks_view.py',
#  u'includes_file_heat/api/openstack/v1/views/views_common.py',
#  u'includes_file_heat/api/openstack/versions.py',
#  u'includes_file_heat/boto_client.py',
#  u'includes_file_heat/boto_client_cloudwatch.py',
#  u'includes_file_heat/cfn_client/__init__.py',
#  u'includes_file_heat/cfn_client/boto_client.py',
#  u'includes_file_heat/cfn_client/boto_client_cloudwatch.py',
#  u'includes_file_heat/cfn_client/client.py',
#  u'includes_file_heat/cfn_client/utils.py',
#  u'includes_file_heat/client.py',
#  u'includes_file_heat/cloudformation.py',
#  u'includes_file_heat/cloudinit/__init__.py',
#  u'includes_file_heat/cloudinit/boothook.sh',
#  u'includes_file_heat/cloudinit/loguserdata.py',
#  u'includes_file_heat/cloudinit/loguserdata.sh',
#  u'includes_file_heat/cloudinit/part-handler.py',
#  u'includes_file_heat/cloudinit/part_handler.py',
#  u'includes_file_heat/cmd/__init__.py',
#  u'includes_file_heat/cmd/manage.py',
#  u'includes_file_heat/common/auth.py',
#  u'includes_file_heat/common/auth_password.py',
#  u'includes_file_heat/common/auth_token.py',
#  u'includes_file_heat/common/auth_url.py',
#  u'includes_file_heat/common/client.py',
#  u'includes_file_heat/common/config.py',
#  u'includes_file_heat/common/context.py',
#  u'includes_file_heat/common/crypt.py',
#  u'includes_file_heat/common/custom_backend_auth.py',
#  u'includes_file_heat/common/ec2signer.py',
#  u'includes_file_heat/common/environment_format.py',
#  u'includes_file_heat/common/exception.py',
#  u'includes_file_heat/common/grouputils.py',
#  u'includes_file_heat/common/heat_keystoneclient.py',
#  u'includes_file_heat/common/i18n.py',
#  u'includes_file_heat/common/identifier.py',
#  u'includes_file_heat/common/lifecycle_plugin_utils.py',
#  u'includes_file_heat/common/messaging.py',
#  u'includes_file_heat/common/notify.py',
#  u'includes_file_heat/common/param_utils.py',
#  u'includes_file_heat/common/plugin_loader.py',
#  u'includes_file_heat/common/policy.py',
#  u'includes_file_heat/common/profiler.py',
#  u'includes_file_heat/common/serializers.py',
#  u'includes_file_heat/common/service_utils.py',
#  u'includes_file_heat/common/short_id.py',
#  u'includes_file_heat/common/systemd.py',
#  u'includes_file_heat/common/template_format.py',
#  u'includes_file_heat/common/timeutils.py',
#  u'includes_file_heat/common/urlfetch.py',
#  u'includes_file_heat/common/utils.py',
#  u'includes_file_heat/common/wsgi.py',
#  u'includes_file_heat/db/__init__.py',
#  u'includes_file_heat/db/api.py',
#  u'includes_file_heat/db/migration.py',
#  u'includes_file_heat/db/sqlalchemy/api.py',
#  u'includes_file_heat/db/sqlalchemy/filters.py',
#  u'includes_file_heat/db/sqlalchemy/manage.py',
#  u'includes_file_heat/db/sqlalchemy/migrate_repo/versions/001_norwhal.py',
#  u'includes_file_heat/db/sqlalchemy/migrate_repo/versions/002_Add_event_data.py',
#  u'includes_file_heat/db/sqlalchemy/migrate_repo/versions/003_add_missing_cols.py',
#  u'includes_file_heat/db/sqlalchemy/migrate_repo/versions/004_guest_watch.py',
#  u'includes_file_heat/db/sqlalchemy/migrate_repo/versions/005_user_creds.py',
#  u'includes_file_heat/db/sqlalchemy/migrate_repo/versions/006_nested_stacks.py',
#  u'includes_file_heat/db/sqlalchemy/migrate_repo/versions/007_resource_work.py',
#  u'includes_file_heat/db/sqlalchemy/migrate_repo/versions/008_user_parameters.py',
#  u'includes_file_heat/db/sqlalchemy/migrate_repo/versions/009_remove_parsed_template.py',
#  u'includes_file_heat/db/sqlalchemy/migrate_repo/versions/010_add_stack_timeout_col.py',
#  u'includes_file_heat/db/sqlalchemy/migrate_repo/versions/011_stack_tenant.py',
#  u'includes_file_heat/db/sqlalchemy/migrate_repo/versions/012_stack_id_uuid.py',
#  u'includes_file_heat/db/sqlalchemy/migrate_repo/versions/013_owner_id_uuid.py',
#  u'includes_file_heat/db/sqlalchemy/migrate_repo/versions/014_watch_stackid.py',
#  u'includes_file_heat/db/sqlalchemy/migrate_repo/versions/015_add_stack_rollback_col.py',
#  u'includes_file_heat/db/sqlalchemy/migrate_repo/versions/015_grizzly.py',
#  u'includes_file_heat/db/sqlalchemy/migrate_repo/versions/016_timeout_nullable.py',
#  u'includes_file_heat/db/sqlalchemy/migrate_repo/versions/017_event_state_status.py',
#  u'includes_file_heat/db/sqlalchemy/migrate_repo/versions/018_resource_id_uuid.py',
#  u'includes_file_heat/db/sqlalchemy/migrate_repo/versions/019_resource_action_status.py',
#  u'includes_file_heat/db/sqlalchemy/migrate_repo/versions/020_stack_action.py',
#  u'includes_file_heat/db/sqlalchemy/migrate_repo/versions/021_resource_data.py',
#  u'includes_file_heat/db/sqlalchemy/migrate_repo/versions/022_stack_event_soft_delete.py',
#  u'includes_file_heat/db/sqlalchemy/migrate_repo/versions/023_raw_template_mysql_longtext.py',
#  u'includes_file_heat/db/sqlalchemy/migrate_repo/versions/024_event_resource_name.py',
#  u'includes_file_heat/db/sqlalchemy/migrate_repo/versions/025_user_creds_drop_service.py',
#  u'includes_file_heat/db/sqlalchemy/migrate_repo/versions/026_user_creds_drop_aws.py',
#  u'includes_file_heat/db/sqlalchemy/migrate_repo/versions/027_user_creds_trusts.py',
#  u'includes_file_heat/db/sqlalchemy/migrate_repo/versions/028_text_mysql_longtext.py',
#  u'includes_file_heat/db/sqlalchemy/migrate_repo/versions/029_event_id_to_uuid.py',
#  u'includes_file_heat/db/sqlalchemy/migrate_repo/versions/030_remove_uuidutils.py',
#  u'includes_file_heat/db/sqlalchemy/migrate_repo/versions/031_stack_lock.py',
#  u'includes_file_heat/db/sqlalchemy/migrate_repo/versions/032_decrypt_method.py',
#  u'includes_file_heat/db/sqlalchemy/migrate_repo/versions/033_software_config.py',
#  u'includes_file_heat/db/sqlalchemy/migrate_repo/versions/034_raw_template_files.py',
#  u'includes_file_heat/db/sqlalchemy/migrate_repo/versions/035_event_uuid_to_id.py',
#  u'includes_file_heat/db/sqlalchemy/migrate_repo/versions/036_stack_domain_project.py',
#  u'includes_file_heat/db/sqlalchemy/migrate_repo/versions/037_migrate_hot_template.py',
#  u'includes_file_heat/db/sqlalchemy/migrate_repo/versions/038_software_config_json_config.py',
#  u'includes_file_heat/db/sqlalchemy/migrate_repo/versions/039_user_creds_nullable.py',
#  u'includes_file_heat/db/sqlalchemy/migrate_repo/versions/040_software_deployment_no_signal_id.py',
#  u'includes_file_heat/db/sqlalchemy/migrate_repo/versions/041_migrate_hot_template_resources.py',
#  u'includes_file_heat/db/sqlalchemy/migrate_repo/versions/042_software_deployment_domain_project.py',
#  u'includes_file_heat/db/sqlalchemy/migrate_repo/versions/043_migrate_template_versions.py',
#  u'includes_file_heat/db/sqlalchemy/migrate_repo/versions/044_snapshots.py',
#  u'includes_file_heat/db/sqlalchemy/migrate_repo/versions/045_stack_backup.py',
#  u'includes_file_heat/db/sqlalchemy/migrate_repo/versions/046_properties_data.py',
#  u'includes_file_heat/db/sqlalchemy/migrate_repo/versions/047_stack_nested_depth.py',
#  u'includes_file_heat/db/sqlalchemy/migrate_repo/versions/048_resource_id_server_default_none_psql.py',
#  u'includes_file_heat/db/sqlalchemy/migrate_repo/versions/049_user_creds_region_name.py',
#  u'includes_file_heat/db/sqlalchemy/migrate_repo/versions/050_stack_tags.py',
#  u'includes_file_heat/db/sqlalchemy/migrate_repo/versions/051_service.py',
#  u'includes_file_heat/db/sqlalchemy/migrate_repo/versions/052_convergence_flag.py',
#  u'includes_file_heat/db/sqlalchemy/migrate_repo/versions/053_stack_name_tenant_indexes.py',
#  u'includes_file_heat/db/sqlalchemy/migrate_repo/versions/054_stack_tags_table.py',
#  u'includes_file_heat/db/sqlalchemy/migrate_repo/versions/055_stack_convg_data.py',
#  u'includes_file_heat/db/sqlalchemy/migration.py',
#  u'includes_file_heat/db/sqlalchemy/models.py',
#  u'includes_file_heat/db/sqlalchemy/mutable.py',
#  u'includes_file_heat/db/sqlalchemy/session.py',
#  u'includes_file_heat/db/sqlalchemy/types.py',
#  u'includes_file_heat/db/sqlalchemy/utils.py',
#  u'includes_file_heat/db/sync.py',
#  u'includes_file_heat/db/utils.py',
#  u'includes_file_heat/doc/__init__.py',
#  u'includes_file_heat/doc/resources.py',
#  u'includes_file_heat/engine/__init__.py',
#  u'includes_file_heat/engine/api.py',
#  u'includes_file_heat/engine/attributes.py',
#  u'includes_file_heat/engine/auth.py',
#  u'includes_file_heat/engine/cfn/__init__.py',
#  u'includes_file_heat/engine/cfn/functions.py',
#  u'includes_file_heat/engine/cfn/template.py',
#  u'includes_file_heat/engine/clients.py',
#  u'includes_file_heat/engine/clients/__init__.py',
#  u'includes_file_heat/engine/clients/client_plugin.py',
#  u'includes_file_heat/engine/clients/os/__init__.py',
#  u'includes_file_heat/engine/clients/os/ceilometer.py',
#  u'includes_file_heat/engine/clients/os/cinder.py',
#  u'includes_file_heat/engine/clients/os/glance.py',
#  u'includes_file_heat/engine/clients/os/heat_plugin.py',
#  u'includes_file_heat/engine/clients/os/keystone.py',
#  u'includes_file_heat/engine/clients/os/neutron.py',
#  u'includes_file_heat/engine/clients/os/nova.py',
#  u'includes_file_heat/engine/clients/os/sahara.py',
#  u'includes_file_heat/engine/clients/os/swift.py',
#  u'includes_file_heat/engine/clients/os/trove.py',
#  u'includes_file_heat/engine/components.py',
#  u'includes_file_heat/engine/constraints.py',
#  u'includes_file_heat/engine/dependencies.py',
#  u'includes_file_heat/engine/environment.py',
#  u'includes_file_heat/engine/event.py',
#  u'includes_file_heat/engine/format.py',
#  u'includes_file_heat/engine/function.py',
#  u'includes_file_heat/engine/hot.py',
#  u'includes_file_heat/engine/hot/__init__.py',
#  u'includes_file_heat/engine/hot/functions.py',
#  u'includes_file_heat/engine/hot/parameters.py',
#  u'includes_file_heat/engine/hot/template.py',
#  u'includes_file_heat/engine/identifier.py',
#  u'includes_file_heat/engine/lifecycle_plugin.py',
#  u'includes_file_heat/engine/notification.py',
#  u'includes_file_heat/engine/notification/__init__.py',
#  u'includes_file_heat/engine/notification/autoscaling.py',
#  u'includes_file_heat/engine/notification/stack.py',
#  u'includes_file_heat/engine/parameter_groups.py',
#  u'includes_file_heat/engine/parameters.py',
#  u'includes_file_heat/engine/parser.py',
#  u'includes_file_heat/engine/plugin_manager.py',
#  u'includes_file_heat/engine/properties.py',
#  u'includes_file_heat/engine/resource.py',
#  u'includes_file_heat/engine/resources/__init__.py',
#  u'includes_file_heat/engine/resources/autoscaling.py',
#  u'includes_file_heat/engine/resources/aws/__init__.py',
#  u'includes_file_heat/engine/resources/aws/autoscaling/__init__.py',
#  u'includes_file_heat/engine/resources/aws/autoscaling/autoscaling_group.py',
#  u'includes_file_heat/engine/resources/aws/autoscaling/scaling_policy.py',
#  u'includes_file_heat/engine/resources/aws/autoscaling_group.py',
#  u'includes_file_heat/engine/resources/aws/cfn/__init__.py',
#  u'includes_file_heat/engine/resources/aws/cfn/stack.py',
#  u'includes_file_heat/engine/resources/aws/cfn/wait_condition.py',
#  u'includes_file_heat/engine/resources/aws/cfn/wait_condition_handle.py',
#  u'includes_file_heat/engine/resources/aws/ec2/__init__.py',
#  u'includes_file_heat/engine/resources/aws/ec2/route_table.py',
#  u'includes_file_heat/engine/resources/aws/ec2/vpc.py',
#  u'includes_file_heat/engine/resources/aws/iam/__init__.py',
#  u'includes_file_heat/engine/resources/aws/iam/user.py',
#  u'includes_file_heat/engine/resources/aws/instance.py',
#  u'includes_file_heat/engine/resources/aws/launch_config.py',
#  u'includes_file_heat/engine/resources/aws/lb/__init__.py',
#  u'includes_file_heat/engine/resources/aws/lb/loadbalancer.py',
#  u'includes_file_heat/engine/resources/aws/s3/__init__.py',
#  u'includes_file_heat/engine/resources/aws/scaling_policy.py',
#  u'includes_file_heat/engine/resources/aws/user.py',
#  u'includes_file_heat/engine/resources/aws/volume.py',
#  u'includes_file_heat/engine/resources/aws/wait_condition.py',
#  u'includes_file_heat/engine/resources/aws/wait_condition_handle.py',
#  u'includes_file_heat/engine/resources/ceilometer/__init__.py',
#  u'includes_file_heat/engine/resources/ceilometer/alarm.py',
#  u'includes_file_heat/engine/resources/cloud_watch.py',
#  u'includes_file_heat/engine/resources/dbinstance.py',
#  u'includes_file_heat/engine/resources/eip.py',
#  u'includes_file_heat/engine/resources/event.py',
#  u'includes_file_heat/engine/resources/glance_image.py',
#  u'includes_file_heat/engine/resources/glance_utils.py',
#  u'includes_file_heat/engine/resources/image.py',
#  u'includes_file_heat/engine/resources/instance.py',
#  u'includes_file_heat/engine/resources/instance_group.py',
#  u'includes_file_heat/engine/resources/internet_gateway.py',
#  u'includes_file_heat/engine/resources/iso_8601.py',
#  u'includes_file_heat/engine/resources/loadbalancer.py',
#  u'includes_file_heat/engine/resources/network_interface.py',
#  u'includes_file_heat/engine/resources/neutron/__init__.py',
#  u'includes_file_heat/engine/resources/neutron/firewall.py',
#  u'includes_file_heat/engine/resources/neutron/floatingip.py',
#  u'includes_file_heat/engine/resources/neutron/loadbalancer.py',
#  u'includes_file_heat/engine/resources/neutron/metering.py',
#  u'includes_file_heat/engine/resources/neutron/net.py',
#  u'includes_file_heat/engine/resources/neutron/network_gateway.py',
#  u'includes_file_heat/engine/resources/neutron/neutron.py',
#  u'includes_file_heat/engine/resources/neutron/neutron_utils.py',
#  u'includes_file_heat/engine/resources/neutron/port.py',
#  u'includes_file_heat/engine/resources/neutron/provider_net.py',
#  u'includes_file_heat/engine/resources/neutron/router.py',
#  u'includes_file_heat/engine/resources/neutron/security_group.py',
#  u'includes_file_heat/engine/resources/neutron/subnet.py',
#  u'includes_file_heat/engine/resources/neutron/vpnservice.py',
#  u'includes_file_heat/engine/resources/nova_floatingip.py',
#  u'includes_file_heat/engine/resources/nova_keypair.py',
#  u'includes_file_heat/engine/resources/nova_servergroup.py',
#  u'includes_file_heat/engine/resources/nova_utils.py',
#  u'includes_file_heat/engine/resources/openstack/__init__.py',
#  u'includes_file_heat/engine/resources/openstack/access_policy.py',
#  u'includes_file_heat/engine/resources/openstack/autoscaling_group.py',
#  u'includes_file_heat/engine/resources/openstack/ha_restarter.py',
#  u'includes_file_heat/engine/resources/openstack/heat/ha_restarter.py',
#  u'includes_file_heat/engine/resources/openstack/heat/instance_group.py',
#  u'includes_file_heat/engine/resources/openstack/heat/remote_stack.py',
#  u'includes_file_heat/engine/resources/openstack/heat/resource_group.py',
#  u'includes_file_heat/engine/resources/openstack/heat/scaling_policy.py',
#  u'includes_file_heat/engine/resources/openstack/heat/software_deployment.py',
#  u'includes_file_heat/engine/resources/openstack/nova/__init__.py',
#  u'includes_file_heat/engine/resources/openstack/nova/server.py',
#  u'includes_file_heat/engine/resources/openstack/scaling_policy.py',
#  u'includes_file_heat/engine/resources/openstack/volume.py',
#  u'includes_file_heat/engine/resources/openstack/wait_condition.py',
#  u'includes_file_heat/engine/resources/openstack/wait_condition_handle.py',
#  u'includes_file_heat/engine/resources/os_database.py',
#  u'includes_file_heat/engine/resources/properties.py',
#  u'includes_file_heat/engine/resources/quantum/__init__.py',
#  u'includes_file_heat/engine/resources/quantum/floatingip.py',
#  u'includes_file_heat/engine/resources/quantum/net.py',
#  u'includes_file_heat/engine/resources/quantum/port.py',
#  u'includes_file_heat/engine/resources/quantum/quantum.py',
#  u'includes_file_heat/engine/resources/quantum/router.py',
#  u'includes_file_heat/engine/resources/quantum/subnet.py',
#  u'includes_file_heat/engine/resources/rackspace/__init__.py',
#  u'includes_file_heat/engine/resources/rackspace/cloud_loadbalancer.py',
#  u'includes_file_heat/engine/resources/rackspace/cloud_server.py',
#  u'includes_file_heat/engine/resources/rackspace/clouddatabase.py',
#  u'includes_file_heat/engine/resources/rackspace/rackspace_resource.py',
#  u'includes_file_heat/engine/resources/random_string.py',
#  u'includes_file_heat/engine/resources/register.py',
#  u'includes_file_heat/engine/resources/remote_stack.py',
#  u'includes_file_heat/engine/resources/resource.py',
#  u'includes_file_heat/engine/resources/resource_group.py',
#  u'includes_file_heat/engine/resources/route_table.py',
#  u'includes_file_heat/engine/resources/s3.py',
#  u'includes_file_heat/engine/resources/sahara_cluster.py',
#  u'includes_file_heat/engine/resources/sahara_templates.py',
#  u'includes_file_heat/engine/resources/security_group.py',
#  u'includes_file_heat/engine/resources/server.py',
#  u'includes_file_heat/engine/resources/software_config/__init__.py',
#  u'includes_file_heat/engine/resources/software_config/cloud_config.py',
#  u'includes_file_heat/engine/resources/software_config/multi_part.py',
#  u'includes_file_heat/engine/resources/software_config/software_component.py',
#  u'includes_file_heat/engine/resources/software_config/software_config.py',
#  u'includes_file_heat/engine/resources/software_config/software_deployment.py',
#  u'includes_file_heat/engine/resources/software_config/structured_config.py',
#  u'includes_file_heat/engine/resources/stack.py',
#  u'includes_file_heat/engine/resources/subnet.py',
#  u'includes_file_heat/engine/resources/swift.py',
#  u'includes_file_heat/engine/resources/swiftsignal.py',
#  u'includes_file_heat/engine/resources/template_resource.py',
#  u'includes_file_heat/engine/resources/user.py',
#  u'includes_file_heat/engine/resources/volume.py',
#  u'includes_file_heat/engine/resources/vpc.py',
#  u'includes_file_heat/engine/resources/wait_condition.py',
#  u'includes_file_heat/engine/rpcapi.py',
#  u'includes_file_heat/engine/rsrc_defn.py',
#  u'includes_file_heat/engine/scheduler.py',
#  u'includes_file_heat/engine/service.py',
#  u'includes_file_heat/engine/service_software_config.py',
#  u'includes_file_heat/engine/service_stack_watch.py',
#  u'includes_file_heat/engine/signal_responder.py',
#  u'includes_file_heat/engine/stack.py',
#  u'includes_file_heat/engine/stack_lock.py',
#  u'includes_file_heat/engine/stack_resource.py',
#  u'includes_file_heat/engine/stack_user.py',
#  u'includes_file_heat/engine/support.py',
#  u'includes_file_heat/engine/template.py',
#  u'includes_file_heat/engine/timestamp.py',
#  u'includes_file_heat/engine/update.py',
#  u'includes_file_heat/engine/volume_tasks.py',
#  u'includes_file_heat/engine/watchrule.py',
#  u'includes_file_heat/engine/worker.py',
#  u'includes_file_heat/openstack/common/__init__.py',
#  u'includes_file_heat/openstack/common/_i18n.py',
#  u'includes_file_heat/openstack/common/cfg.py',
#  u'includes_file_heat/openstack/common/cliutils.py',
#  u'includes_file_heat/openstack/common/config/__init__.py',
#  u'includes_file_heat/openstack/common/config/generator.py',
#  u'includes_file_heat/openstack/common/context.py',
#  u'includes_file_heat/openstack/common/crypto/__init__.py',
#  ...]
