# %%
# %matplotlib inline
from pprint import pprint
from collections import defaultdict

import numpy as np
import math
import matplotlib.pyplot as plt
import random
import warnings

#from sklearn.linear_model import LogisticRegression
#from sklearn.svm import SVC
#from sklearn.naive_bayes import GaussianNB
#from sklearn.linear_model import SGDClassifier
import sklearn.tree
import sklearn.ensemble

from sklearn.grid_search import GridSearchCV
from sklearn import metrics

import sys
sys.path.append('./dev')

from ml_plot import plot_validation_curve
from ml_plot import PredictCV, my_plot_learning_curve
from ml_plot import plot_prediction_curve
from ml_plot import get_dataset, eval_predictions

# %% [markdown]
# # Configuration

# %%
# PROJECT = 'nova'
# PROJECT = 'swift'
# PROJECT = 'cinder'
PROJECT = 'heat'
# PROJECT = 'glance'

# IMPORTANCE = 'crit'
# IMPORTANCE = 'high+'
IMPORTANCE = 'med+'
# IMPORTANCE = 'low+'

# SIZE = 100
#SIZE = 250
# SIZE = 0.1
SIZE = 0.5

SCORING = 'f1'         # (precision * recall) / (precision + recall)
# SCORING = 'accuracy'   # (TP + TN) / all values
# SCORING = 'precision'  # TP / (TP + FP)
# SCORING = 'recall'     # TP / (TP + FN)
# SCORING = 'average_precision'
# SCORING = 'roc_auc'

JOBS = 4

VERBOSE = 0

#warnings.simplefilter("ignore", UndefinedMetricWarning)
warnings.filterwarnings('ignore', 'F-score is ill-defined')
warnings.filterwarnings('ignore', 'overflow encountered in exp')

# %% [markdown]
# # Load Data

# %%
# %%capture
Y, X = get_dataset(PROJECT, IMPORTANCE)

# %% [markdown]
# ### Select Split Strategy

# %%
cv = PredictCV(len(Y), history=500, future=300, n_iter=10)

# %% [markdown]
# # Gradient Tree

# %%
estimator = sklearn.ensemble.GradientBoostingClassifier()
param_grid = {'learning_rate': [0.5, 1.0, 2.0],
              'n_estimators': [25, 50, 100],
              'max_features': [None, 'auto', 'log2']}

# %%
grid = GridSearchCV(estimator, param_grid=param_grid, cv=cv, scoring=SCORING,
                    n_jobs=JOBS, pre_dispatch=2*JOBS, verbose=VERBOSE)
grid.fit(X, Y)
print 'best_score: ', grid.best_score_
clf = grid.best_estimator_
grid.best_estimator_
# Out:
# best_score:  0.426955713762
# /Users/doug/anaconda/lib/python2.7/site-packages/sklearn/ensemble/gradient_boosting.py:397: RuntimeWarning: overflow encountered in double_scalars
#   tree.value[leaf, 0, 0] = numerator / denominator
# /Users/doug/anaconda/lib/python2.7/site-packages/sklearn/ensemble/gradient_boosting.py:371: RuntimeWarning: invalid value encountered in multiply
#   return -2.0 * np.mean((y * pred) - np.logaddexp(0.0, pred))
# /Users/doug/anaconda/lib/python2.7/site-packages/sklearn/ensemble/gradient_boosting.py:371: RuntimeWarning: invalid value encountered in subtract
#   return -2.0 * np.mean((y * pred) - np.logaddexp(0.0, pred))
# GradientBoostingClassifier(init=None, learning_rate=1.0, loss='deviance',
#               max_depth=3, max_features='auto', max_leaf_nodes=None,
#               min_samples_leaf=1, min_samples_split=2, n_estimators=100,
#               random_state=None, subsample=1.0, verbose=0,
#               warm_start=False)

# %% [markdown]
# ### Validation Curve

# %%
best_score, param_val, param_name = \
    plot_validation_curve(clf,
                          X, Y,
                          "learning_rate", [0.5, 1.0, 2.0],
                          "learning_rate Validation Curve",
                          cv=cv, scoring=SCORING, n_jobs=JOBS)
print 'Best score of', best_score, 'when setting', param_name, 'to',  param_val
# Out:
# Best score of 0.389333187257 when setting learning_rate to 1.0

# %%
best_score, param_val, param_name = \
    plot_validation_curve(clf,
                          X, Y,
                          "n_estimators", [25, 50, 100],
                          "n_estimators Validation Curve",
                          cv=cv, scoring=SCORING, n_jobs=JOBS)
print 'Best score of', best_score, 'when setting', param_name, 'to',  param_val
# Out:
# Best score of 0.377889276018 when setting n_estimators to 50

# %% [markdown]
# ### Learning Curve

# %%
title = "Learning Curves for Gradient Tree using DecisionTreeClassifier"
my_plot_learning_curve(clf, title, X, Y,
                           n_jobs=JOBS, future=500,
                           history_sizes=[200, 300, 400, 500, 600, 750, 1000])
plt.show()

# %% [markdown]
# ### Prediction Curve

# %%
title = "Prediction Horizon Curve for Gradient Tree with DecisionTreeClassifier"
plot_prediction_curve(clf, title, X, Y,
                           n_jobs=JOBS, history=500,
                           future_sizes=[100, 200, 300, 500])
plt.show()

# %%
GT_results = eval_predictions(clf, X, Y, history_sizes=[500, 1000], future_sizes=[100, 300, 500])
# Out:
# ** Predictions for hist=500 future=100 **
#
# F1:        0.41  +/- 0.18
# Accuracy:  0.71  +/- 0.11
# Precision: 0.48  +/- 0.23
# Recall:    0.40  +/- 0.19
#
# Aggregate Confusion Matrix - 10 iterations
# [[581 126]
#  [161 132]]
#
#
# ** Predictions for hist=500 future=300 **
# F1:        0.34  +/- 0.12
# Accuracy:  0.74  +/- 0.08
# Precision: 0.36  +/- 0.08
# Recall:    0.36  +/- 0.18
#
# Aggregate Confusion Matrix - 10 iterations
# [[1986  407]
#  [ 372  235]]
#
#
# ** Predictions for hist=500 future=500 **
# F1:        0.39  +/- 0.07
# Accuracy:  0.65  +/- 0.12
# Precision: 0.39  +/- 0.11
# Recall:    0.44  +/- 0.13
#
# Aggregate Confusion Matrix - 10 iterations
# [[2708  984]
#  [ 743  565]]
#
#
# ** Predictions for hist=1000 future=100 **
# F1:        0.36  +/- 0.11
# Accuracy:  0.77  +/- 0.07
# Precision: 0.39  +/- 0.11
# Recall:    0.37  +/- 0.14
#
# Aggregate Confusion Matrix - 10 iterations
# [[689 114]
#  [121  76]]
#
#
# ** Predictions for hist=1000 future=300 **
# F1:        0.37  +/- 0.05
# Accuracy:  0.72  +/- 0.07
# Precision: 0.36  +/- 0.05
# Recall:    0.40  +/- 0.09
#
# Aggregate Confusion Matrix - 10 iterations
# [[1896  458]
#  [ 386  260]]
#
#
# ** Predictions for hist=1000 future=500 **
# F1:        0.39  +/- 0.09
# Accuracy:  0.74  +/- 0.04
# Precision: 0.38  +/- 0.09
# Recall:    0.42  +/- 0.12
#
# Aggregate Confusion Matrix - 10 iterations
# [[3267  684]
#  [ 601  448]]
# /Users/doug/anaconda/lib/python2.7/site-packages/sklearn/metrics/metrics.py:1771: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
GT_clf = clf
